# %%
# !pip install --upgrade keras==2.15.0
# !pip install --upgrade tensorflow==2.15.0.post1
# !pip install --upgrade scipy==1.11.4
# !pip install tensorflow-addons==0.21.0

# clone Impala repository, refresh folder to see the Imapala repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Impala
# Out:
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow==2.15.0.post1
#   Downloading tensorflow-2.15.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.66.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0.post1) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.2.2)
# Downloading tensorflow-2.15.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 792.0 kB/s eta 0:00:00
# Installing collected packages: tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# Successfully installed tensorflow-2.15.0.post1
# Collecting scipy==1.11.4
#   Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 827.6 kB/s eta 0:00:00
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy==1.11.4) (1.26.4)
# Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 33.9 MB/s eta 0:00:00
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# Successfully installed scipy-1.11.4
# Collecting tensorflow-addons==0.21.0
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.21.0) (24.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons==0.21.0)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 4.0 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3
# Cloning into 'Impala'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 235 (delta 4), reused 31 (delta 4), pack-reused 204 (from 1)
# Receiving objects: 100% (235/235), 1.09 GiB | 46.60 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Updating files: 100% (206/206), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
# architecture
image_size = 256
filters = 256
depth = 4
columns = 4
widths = 4
kernel_size = 5
patch_size = 16
num_classes = 3

in_channel = 9
img_rows, img_cols = image_size, image_size
input_shape = (img_rows, img_cols, in_channel)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 20

# varibale for tokenizer
NUM_PATCHES = 16

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "scal"
exp_name = f"impala3d_v3_hexa"
sub_exp_name = "regression"
model_name = f"{exp_name}_{sub_exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

# dataset
csv_path = "/content/Impala/dataset/labels_reg_sample.csv"
scal_path = f"/content/Impala/dataset/{modality}"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/scal/chips/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["scal_x"] = train_df.id.map(lambda id: f"{scal_path}/x/{id}.png")
test_df["scal_x"] = test_df.id.map(lambda id: f"{scal_path}/x/{id}.png")
val_df["scal_x"] = val_df.id.map(lambda id: f"{scal_path}/x/{id}.png")

train_df["scal_y"] = train_df.id.map(lambda id: f"{scal_path}/y/{id}.png")
test_df["scal_y"] = test_df.id.map(lambda id: f"{scal_path}/y/{id}.png")
val_df["scal_y"] = val_df.id.map(lambda id: f"{scal_path}/y/{id}.png")

train_df["scal_z"] = train_df.id.map(lambda id: f"{scal_path}/z/{id}.png")
test_df["scal_z"] = test_df.id.map(lambda id: f"{scal_path}/z/{id}.png")
val_df["scal_z"] = val_df.id.map(lambda id: f"{scal_path}/z/{id}.png")
# Out:
# size check train/test/val 14 3 3 20

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))
sns.histplot(train_df["gaps"], ax=ax[0])
sns.histplot(train_df["flank_wear"], ax=ax[1])
sns.histplot(train_df["overhang"], ax=ax[2])
ax[0].set_title("Label Distribution")
ax[1].set_title("Label Distribution")
ax[2].set_title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                         scal_x  \
# 14   /content/Impala/dataset/scal/x/T8R3B4.png
# 10   /content/Impala/dataset/scal/x/T6R9B3.png
# 0    /content/Impala/dataset/scal/x/T1R2B1.png
# 3   /content/Impala/dataset/scal/x/T2R13B4.png
# 1    /content/Impala/dataset/scal/x/T1R7B4.png
#
#                                         scal_y  \
# 14   /content/Impala/dataset/scal/y/T8R3B4.png
# 10   /content/Impala/dataset/scal/y/T6R9B3.png
# 0    /content/Impala/dataset/scal/y/T1R2B1.png
# 3   /content/Impala/dataset/scal/y/T2R13B4.png
# 1    /content/Impala/dataset/scal/y/T1R7B4.png
#
#                                         scal_z
# 14   /content/Impala/dataset/scal/z/T8R3B4.png
# 10   /content/Impala/dataset/scal/z/T6R9B3.png
# 0    /content/Impala/dataset/scal/z/T1R2B1.png
# 3   /content/Impala/dataset/scal/z/T2R13B4.png
# 1    /content/Impala/dataset/scal/z/T1R7B4.png
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                         scal_x  \
# 16   /content/Impala/dataset/scal/x/T9R7B4.png
# 18  /content/Impala/dataset/scal/x/T10R3B4.png
# 9   /content/Impala/dataset/scal/x/T5R12B1.png
#
#                                         scal_y  \
# 16   /content/Impala/dataset/scal/y/T9R7B4.png
# 18  /content/Impala/dataset/scal/y/T10R3B4.png
# 9   /content/Impala/dataset/scal/y/T5R12B1.png
#
#                                         scal_z
# 16   /content/Impala/dataset/scal/z/T9R7B4.png
# 18  /content/Impala/dataset/scal/z/T10R3B4.png
# 9   /content/Impala/dataset/scal/z/T5R12B1.png
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                         scal_x  \
# 5   /content/Impala/dataset/scal/x/T3R10B1.png
# 13  /content/Impala/dataset/scal/x/T7R14B3.png
# 12   /content/Impala/dataset/scal/x/T7R8B3.png
#
#                                         scal_y  \
# 5   /content/Impala/dataset/scal/y/T3R10B1.png
# 13  /content/Impala/dataset/scal/y/T7R14B3.png
# 12   /content/Impala/dataset/scal/y/T7R8B3.png
#
#                                         scal_z
# 5   /content/Impala/dataset/scal/z/T3R10B1.png
# 13  /content/Impala/dataset/scal/z/T7R14B3.png
# 12   /content/Impala/dataset/scal/z/T7R8B3.png

# %%
def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []
    for i in range(file_paths_x.size):
        img = []
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_x)

        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_y)

        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_z)
        img = np.concatenate(img, axis=2)
        images.append(img)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    return images

# %%
x_train_scal = read_specs(
    train_df.scal_x.values,
    train_df.scal_y.values,
    train_df.scal_z.values,
    img_rows,
    img_cols,
    in_channel,
)
x_test_scal = read_specs(
    test_df.scal_x.values,
    test_df.scal_y.values,
    test_df.scal_z.values,
    img_rows,
    img_cols,
    in_channel,
)
x_val_scal = read_specs(
    val_df.scal_x.values,
    val_df.scal_y.values,
    val_df.scal_z.values,
    img_rows,
    img_cols,
    in_channel,
)

# %%
x_train_scal.shape
# Out:
# (14, 256, 256, 9)

# %%
pil_img_x = tf.keras.utils.array_to_img(np.flip(x_train_scal[0][:,:,:3],axis=-1))
pil_img_y = tf.keras.utils.array_to_img(np.flip(x_train_scal[0][:,:,3:6],axis=-1))
pil_img_z = tf.keras.utils.array_to_img(np.flip(x_train_scal[0][:,:,6:9],axis=-1))

fig, ax = plt.subplots(1,3, figsize=(12,4))
ax[0].imshow(pil_img_x)
ax[1].imshow(pil_img_y)
ax[2].imshow(pil_img_z)
ax[0].set_title("scal_x")
ax[1].set_title("scal_y")
ax[2].set_title("scal_z")
plt.show()

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_scal, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_scal, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_scal, labels_val))

# %%
# ============================== augment ==============================
auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation",
)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
# https://keras.io/examples/vision/token_learner/
def patch_attention(inputs, number_of_paches=NUM_PATCHES):
    # Layer normalize the inputs.
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)  # (B, H, W, C)

    # Applying Conv2D => Reshape => Permute
    # The reshape and permute is done to help with the next steps of
    # multiplication and Global Average Pooling.
    attention_maps = k.Sequential(
        [
            # 3 layers of conv with gelu activation as suggested
            # in the paper.
            layers.Conv2D(
                filters=number_of_paches,
                kernel_size=(3, 3),
                activation=tf.nn.gelu,
                padding="same",
                use_bias=False,
            ),
            layers.Conv2D(
                filters=number_of_paches,
                kernel_size=(3, 3),
                activation=tf.nn.gelu,
                padding="same",
                use_bias=False,
            ),
            layers.Conv2D(
                filters=number_of_paches,
                kernel_size=(3, 3),
                activation=tf.nn.gelu,
                padding="same",
                use_bias=False,
            ),
            # This conv layer will generate the attention maps
            layers.Conv2D(
                filters=number_of_paches,
                kernel_size=(3, 3),
                activation="sigmoid",  # Note sigmoid for [0, 1] output
                padding="same",
                use_bias=False,
            ),
            # Reshape and Permute
            layers.Reshape((-1, number_of_paches)),  # (B, H*W, num_of_paches)
            layers.Permute((2, 1)),
        ]
    )(
        x
    )  # (B, num_of_paches, H*W)

    # Reshape the input to align it with the output of the conv block.
    num_filters = inputs.shape[-1]
    inputs = layers.Reshape((1, -1, num_filters))(inputs)  # inputs == (B, 1, H*W, C)

    # Element-Wise multiplication of the attention maps and the inputs
    attended_inputs = (
        attention_maps[..., tf.newaxis] * inputs
    )  # (B, num_tokens, H*W, C)

    outputs = tf.reduce_mean(attended_inputs, axis=1)

    # Instead of GAP, reshape the tensor back to the original shape
    outputs = layers.Reshape((patch_size, patch_size, num_filters))(outputs)

    return outputs

# %%
def activation_module(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def base_module(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_module(x)


def depth_point_module(
    x, pe_block, column, level, depth, width, r_arr, filters: int, kernel_size: int
):
    if column == 0:
        # Depthwise convolution.
        x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        if width != 0:
            x0 = fusion_block_double(r_arr[width - 1][column][level], x0)

        r_arr = reverasable_output_array(x, r_arr, width, column, level)
        return x, r_arr
    elif column != 0:
        if level == 0:
            x0 = fusion_block_double(r_arr[width][column - 1][level + 1], pe_block)
        elif level <= depth - 2:
            x0 = fusion_block_double(r_arr[width][column - 1][level + 1], x)
            if width != 0:
                x = fusion_block_double(r_arr[width - 1][column - 1][level + 1], x)
        else:
            x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x0)
        x = layers.Add()([activation_module(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_module(x)

        x = fusion_block_double(r_arr[width][column - 1][level], x)
        if width != 0:
            x = fusion_block_double(r_arr[width - 1][column][level], x)

        r_arr = reverasable_output_array(x, r_arr, width, column, level)

        return x, r_arr

    return x, r_arr


def fusion_block_double(x, y):
    return layers.Add()([x, y])


def reverasable_output_array(x, r_arr, width, column, level):
    r_arr[width][column][level] = x
    return r_arr


def load_depth_point(
    image_size=image_size,
    filters=filters,
    depth=depth,
    columns=columns,
    width=widths,
    kernel_size=kernel_size,
    patch_size=patch_size,
    num_classes=num_classes,
):
    r_arr = [
        [[None for _ in range(depth)] for _ in range(columns)] for _ in range(width)
    ]

    inputs = k.Input(input_shape)
    # x = layers.Rescaling(scale=1.0 / 255)(inputs)         # already rescaled

    # Extract patch embeddings.
    x = base_module(inputs, filters, patch_size)
    pe_block = x

    # ConvMixer blocks.
    for w in range(width):
        for column in range(columns):
            for level in range(depth):
                if level == (depth // 2) and column == (columns // 2) and w == (width // 2):
                    print("created tokenizer")
                    x = patch_attention(x)
                x, r_arr = depth_point_module(
                    x, pe_block, column, level, depth, w, r_arr, filters, kernel_size
                )

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="linear")(x)

    return k.Model(inputs, outputs)

# %%
# ============================== run experiment ==============================
def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        verbose=2,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = load_depth_point()
model.summary()
# Out:
# created tokenizer
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 9)]        0         []
#
#  conv2d (Conv2D)             (None, 16, 16, 256)          590080    ['input_1[0][0]']
#
#  activation (Activation)     (None, 16, 16, 256)          0         ['conv2d[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 256)          1024      ['activation[0][0]']
#  Normalization)
#
#  depthwise_conv2d (Depthwis  (None, 16, 16, 256)          6656      ['batch_normalization[0][0]']
#  eConv2D)
#
#  activation_1 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 16, 256)          1024      ['activation_1[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 16, 16, 256)          0         ['batch_normalization_1[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)          65792     ['add[0][0]']
#
#  activation_2 (Activation)   (None, 16, 16, 256)          0         ['conv2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 16, 256)          1024      ['activation_2[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_1 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_2[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_3 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 16, 256)          1024      ['activation_3[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_2[0][0]
#                                                                     ']
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)          65792     ['add_1[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 256)          0         ['conv2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 16, 16, 256)          1024      ['activation_4[0][0]']
#  chNormalization)
#
#  add_4 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  depthwise_conv2d_4 (Depthw  (None, 16, 16, 256)          6656      ['add_4[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_2 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_4[0][0]']
#
#  activation_5 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 256)          1024      ['activation_9[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 16, 16, 256)          1024      ['activation_5[0][0]']
#  chNormalization)
#
#  add_5 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     , 'add_4[0][0]']
#
#  add_2 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)          65792     ['add_5[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)          65792     ['add_2[0][0]']
#
#  activation_10 (Activation)  (None, 16, 16, 256)          0         ['conv2d_5[0][0]']
#
#  activation_6 (Activation)   (None, 16, 16, 256)          0         ['conv2d_3[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 256)          1024      ['activation_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_6 (Bat  (None, 16, 16, 256)          1024      ['activation_6[0][0]']
#  chNormalization)
#
#  add_6 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_2[0][0]'
#                                                                     , 'batch_normalization_10[0][0
#                                                                     ]']
#
#  add_7 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'add_6[0][0]']
#
#  depthwise_conv2d_5 (Depthw  (None, 16, 16, 256)          6656      ['add_7[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_3 (Depthw  (None, 16, 16, 256)          6656      ['batch_normalization_6[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_11 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_5[0][0]']
#
#  activation_7 (Activation)   (None, 16, 16, 256)          0         ['depthwise_conv2d_3[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 256)          1024      ['activation_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_7 (Bat  (None, 16, 16, 256)          1024      ['activation_7[0][0]']
#  chNormalization)
#
#  add_8 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  add_3 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)          65792     ['add_8[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          65792     ['add_3[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 256)          0         ['conv2d_6[0][0]']
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['conv2d_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 256)          1024      ['activation_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_8 (Bat  (None, 16, 16, 256)          1024      ['activation_8[0][0]']
#  chNormalization)
#
#  add_9 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization_12[0][0
#                                                                     ]']
#
#  add_10 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'add_9[0][0]']
#
#  add_15 (Add)                (None, 16, 16, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_6 (Depthw  (None, 16, 16, 256)          6656      ['add_10[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_8 (Depthw  (None, 16, 16, 256)          6656      ['add_15[0][0]']
#  iseConv2D)
#
#  activation_13 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_6[0][0]']
#
#  activation_17 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_8[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 256)          1024      ['activation_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 16, 16, 256)          1024      ['activation_17[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'add_10[0][0]']
#
#  add_16 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 256)          65792     ['add_11[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          65792     ['add_16[0][0]']
#
#  activation_14 (Activation)  (None, 16, 16, 256)          0         ['conv2d_7[0][0]']
#
#  activation_18 (Activation)  (None, 16, 16, 256)          0         ['conv2d_9[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 256)          1024      ['activation_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 16, 16, 256)          1024      ['activation_18[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_14[0][0
#                                                                     ]']
#
#  add_17 (Add)                (None, 16, 16, 256)          0         ['add_6[0][0]',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 16, 16, 256)          0         ['add_12[0][0]',
#                                                                      'add_17[0][0]']
#
#  depthwise_conv2d_7 (Depthw  (None, 16, 16, 256)          6656      ['add_12[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_9 (Depthw  (None, 16, 16, 256)          6656      ['add_18[0][0]']
#  iseConv2D)
#
#  activation_15 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_7[0][0]']
#
#  activation_19 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_9[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 256)          1024      ['activation_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 16, 16, 256)          1024      ['activation_19[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'add_12[0][0]']
#
#  add_19 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'add_18[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          65792     ['add_13[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)          65792     ['add_19[0][0]']
#
#  activation_16 (Activation)  (None, 16, 16, 256)          0         ['conv2d_8[0][0]']
#
#  activation_20 (Activation)  (None, 16, 16, 256)          0         ['conv2d_10[0][0]']
#
#  batch_normalization_16 (Ba  (None, 16, 16, 256)          1024      ['activation_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 16, 16, 256)          1024      ['activation_20[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_16[0][0
#                                                                     ]']
#
#  add_20 (Add)                (None, 16, 16, 256)          0         ['add_9[0][0]',
#                                                                      'batch_normalization_20[0][0]
#                                                                     ']
#
#  add_21 (Add)                (None, 16, 16, 256)          0         ['add_14[0][0]',
#                                                                      'add_20[0][0]']
#
#  add_26 (Add)                (None, 16, 16, 256)          0         ['add_20[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_10 (Depth  (None, 16, 16, 256)          6656      ['add_21[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_12 (Depth  (None, 16, 16, 256)          6656      ['add_26[0][0]']
#  wiseConv2D)
#
#  activation_21 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_10[0][0]']
#
#  activation_25 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_12[0][0]']
#
#  batch_normalization_21 (Ba  (None, 16, 16, 256)          1024      ['activation_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 16, 16, 256)          1024      ['activation_25[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'add_21[0][0]']
#
#  add_27 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ',
#                                                                      'add_26[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)          65792     ['add_22[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 256)          65792     ['add_27[0][0]']
#
#  activation_22 (Activation)  (None, 16, 16, 256)          0         ['conv2d_11[0][0]']
#
#  activation_26 (Activation)  (None, 16, 16, 256)          0         ['conv2d_13[0][0]']
#
#  batch_normalization_22 (Ba  (None, 16, 16, 256)          1024      ['activation_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 16, 16, 256)          1024      ['activation_26[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 16, 16, 256)          0         ['add_12[0][0]',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  add_28 (Add)                (None, 16, 16, 256)          0         ['add_17[0][0]',
#                                                                      'batch_normalization_26[0][0]
#                                                                     ']
#
#  add_29 (Add)                (None, 16, 16, 256)          0         ['add_23[0][0]',
#                                                                      'add_28[0][0]']
#
#  depthwise_conv2d_11 (Depth  (None, 16, 16, 256)          6656      ['add_23[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_13 (Depth  (None, 16, 16, 256)          6656      ['add_29[0][0]']
#  wiseConv2D)
#
#  activation_23 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_11[0][0]']
#
#  activation_27 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_13[0][0]']
#
#  batch_normalization_23 (Ba  (None, 16, 16, 256)          1024      ['activation_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 16, 16, 256)          1024      ['activation_27[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'add_23[0][0]']
#
#  add_30 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'add_29[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 256)          65792     ['add_24[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)          65792     ['add_30[0][0]']
#
#  activation_24 (Activation)  (None, 16, 16, 256)          0         ['conv2d_12[0][0]']
#
#  activation_28 (Activation)  (None, 16, 16, 256)          0         ['conv2d_14[0][0]']
#
#  batch_normalization_24 (Ba  (None, 16, 16, 256)          1024      ['activation_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 16, 16, 256)          1024      ['activation_28[0][0]']
#  tchNormalization)
#
#  add_25 (Add)                (None, 16, 16, 256)          0         ['add_14[0][0]',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ']
#
#  add_31 (Add)                (None, 16, 16, 256)          0         ['add_20[0][0]',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  add_32 (Add)                (None, 16, 16, 256)          0         ['add_25[0][0]',
#                                                                      'add_31[0][0]']
#
#  depthwise_conv2d_14 (Depth  (None, 16, 16, 256)          6656      ['add_32[0][0]']
#  wiseConv2D)
#
#  activation_29 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_14[0][0]']
#
#  batch_normalization_29 (Ba  (None, 16, 16, 256)          1024      ['activation_29[0][0]']
#  tchNormalization)
#
#  add_33 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'add_32[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 256)          65792     ['add_33[0][0]']
#
#  activation_30 (Activation)  (None, 16, 16, 256)          0         ['conv2d_15[0][0]']
#
#  batch_normalization_30 (Ba  (None, 16, 16, 256)          1024      ['activation_30[0][0]']
#  tchNormalization)
#
#  add_34 (Add)                (None, 16, 16, 256)          0         ['add_23[0][0]',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  depthwise_conv2d_15 (Depth  (None, 16, 16, 256)          6656      ['add_34[0][0]']
#  wiseConv2D)
#
#  activation_31 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_15[0][0]']
#
#  batch_normalization_31 (Ba  (None, 16, 16, 256)          1024      ['activation_31[0][0]']
#  tchNormalization)
#
#  add_35 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ',
#                                                                      'add_34[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 256)          65792     ['add_35[0][0]']
#
#  activation_32 (Activation)  (None, 16, 16, 256)          0         ['conv2d_16[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 16, 256)          1024      ['activation_32[0][0]']
#  tchNormalization)
#
#  add_36 (Add)                (None, 16, 16, 256)          0         ['add_25[0][0]',
#                                                                      'batch_normalization_32[0][0]
#                                                                     ']
#
#  depthwise_conv2d_16 (Depth  (None, 16, 16, 256)          6656      ['add_36[0][0]']
#  wiseConv2D)
#
#  activation_33 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_16[0][0]']
#
#  batch_normalization_33 (Ba  (None, 16, 16, 256)          1024      ['activation_33[0][0]']
#  tchNormalization)
#
#  add_37 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'add_36[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 256)          65792     ['add_37[0][0]']
#
#  activation_34 (Activation)  (None, 16, 16, 256)          0         ['conv2d_17[0][0]']
#
#  batch_normalization_34 (Ba  (None, 16, 16, 256)          1024      ['activation_34[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_17 (Depth  (None, 16, 16, 256)          6656      ['batch_normalization_34[0][0]
#  wiseConv2D)                                                        ']
#
#  activation_35 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_17[0][0]']
#
#  batch_normalization_35 (Ba  (None, 16, 16, 256)          1024      ['activation_35[0][0]']
#  tchNormalization)
#
#  add_39 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_35[0][0]
#                                                                     ',
#                                                                      'batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 256)          65792     ['add_39[0][0]']
#
#  activation_36 (Activation)  (None, 16, 16, 256)          0         ['conv2d_18[0][0]']
#
#  batch_normalization_36 (Ba  (None, 16, 16, 256)          1024      ['activation_36[0][0]']
#  tchNormalization)
#
#  add_45 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_36[0][0]
#                                                                     ',
#                                                                      'batch_normalization[0][0]']
#
#  depthwise_conv2d_20 (Depth  (None, 16, 16, 256)          6656      ['add_45[0][0]']
#  wiseConv2D)
#
#  activation_41 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_20[0][0]']
#
#  depthwise_conv2d_18 (Depth  (None, 16, 16, 256)          6656      ['batch_normalization_36[0][0]
#  wiseConv2D)                                                        ']
#
#  batch_normalization_41 (Ba  (None, 16, 16, 256)          1024      ['activation_41[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 16, 16, 256)          0         ['depthwise_conv2d_18[0][0]']
#
#  add_46 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_41[0][0]
#                                                                     ',
#                                                                      'add_45[0][0]']
#
#  batch_normalization_37 (Ba  (None, 16, 16, 256)          1024      ['activation_37[0][0]']
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 256)          65792     ['add_46[0][0]']
#
#  add_41 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_37[0][0]
#                                                                     ',
#                                                                      'batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 16, 16, 256)          0         ['conv2d_21[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 256)          65792     ['add_41[0][0]']
#
#  batch_normalization_42 (Ba  (None, 16, 16, 256)          1024      ['activation_42[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 16, 16, 256)          0         ['conv2d_19[0][0]']
#
#  add_47 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_34[0][0]
#                                                                     ',
#                                                                      'batch_normalization_42[0][0]
#                                                                     ']
#
#  batch_normalization_38 (Ba  (None, 16, 16, 256)          1024      ['activation_38[0][0]']
#  tchNormalization)
#
#  add_48 (Add)                (None, 16, 16, 256)          0         ['add_6[0][0]',
#                                                                      'add_47[0][0]']
#
#  add_49 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_38[0][0]
#                                                                     ',
#                                                                      'add_48[0][0]']
#
#  depthwise_conv2d_21 (Depth  (None, 16, 16, 256)          6656      ['add_49[0][0]']
# ...
#  add_198 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_121[0][0
#                                                                     ]',
#                                                                      'add_197[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 16, 16, 256)          65792     ['add_191[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 16, 16, 256)          65792     ['add_198[0][0]']
#
#  activation_118 (Activation  (None, 16, 16, 256)          0         ['conv2d_63[0][0]']
#  )
#
#  activation_122 (Activation  (None, 16, 16, 256)          0         ['conv2d_65[0][0]']
#  )
#
#  batch_normalization_118 (B  (None, 16, 16, 256)          1024      ['activation_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_122 (B  (None, 16, 16, 256)          1024      ['activation_122[0][0]']
#  atchNormalization)
#
#  add_192 (Add)               (None, 16, 16, 256)          0         ['add_176[0][0]',
#                                                                      'batch_normalization_118[0][0
#                                                                     ]']
#
#  add_199 (Add)               (None, 16, 16, 256)          0         ['add_183[0][0]',
#                                                                      'batch_normalization_122[0][0
#                                                                     ]']
#
#  add_193 (Add)               (None, 16, 16, 256)          0         ['add_134[0][0]',
#                                                                      'add_192[0][0]']
#
#  add_200 (Add)               (None, 16, 16, 256)          0         ['add_141[0][0]',
#                                                                      'add_199[0][0]']
#
#  add_201 (Add)               (None, 16, 16, 256)          0         ['add_193[0][0]',
#                                                                      'add_200[0][0]']
#
#  depthwise_conv2d_59 (Depth  (None, 16, 16, 256)          6656      ['add_193[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_61 (Depth  (None, 16, 16, 256)          6656      ['add_201[0][0]']
#  wiseConv2D)
#
#  activation_119 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_59[0][0]']
#  )
#
#  activation_123 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_61[0][0]']
#  )
#
#  batch_normalization_119 (B  (None, 16, 16, 256)          1024      ['activation_119[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 16, 16, 256)          1024      ['activation_123[0][0]']
#  atchNormalization)
#
#  add_194 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_119[0][0
#                                                                     ]',
#                                                                      'add_193[0][0]']
#
#  add_203 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_123[0][0
#                                                                     ]',
#                                                                      'add_201[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 16, 16, 256)          65792     ['add_194[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 16, 16, 256)          65792     ['add_203[0][0]']
#
#  activation_120 (Activation  (None, 16, 16, 256)          0         ['conv2d_64[0][0]']
#  )
#
#  activation_124 (Activation  (None, 16, 16, 256)          0         ['conv2d_66[0][0]']
#  )
#
#  batch_normalization_120 (B  (None, 16, 16, 256)          1024      ['activation_120[0][0]']
#  atchNormalization)
#
#  batch_normalization_124 (B  (None, 16, 16, 256)          1024      ['activation_124[0][0]']
#  atchNormalization)
#
#  add_195 (Add)               (None, 16, 16, 256)          0         ['add_179[0][0]',
#                                                                      'batch_normalization_120[0][0
#                                                                     ]']
#
#  add_204 (Add)               (None, 16, 16, 256)          0         ['add_188[0][0]',
#                                                                      'batch_normalization_124[0][0
#                                                                     ]']
#
#  add_196 (Add)               (None, 16, 16, 256)          0         ['add_137[0][0]',
#                                                                      'add_195[0][0]']
#
#  add_205 (Add)               (None, 16, 16, 256)          0         ['add_146[0][0]',
#                                                                      'add_204[0][0]']
#
#  add_206 (Add)               (None, 16, 16, 256)          0         ['add_196[0][0]',
#                                                                      'add_205[0][0]']
#
#  depthwise_conv2d_62 (Depth  (None, 16, 16, 256)          6656      ['add_206[0][0]']
#  wiseConv2D)
#
#  activation_125 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_62[0][0]']
#  )
#
#  batch_normalization_125 (B  (None, 16, 16, 256)          1024      ['activation_125[0][0]']
#  atchNormalization)
#
#  add_208 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_125[0][0
#                                                                     ]',
#                                                                      'add_206[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 16, 16, 256)          65792     ['add_208[0][0]']
#
#  activation_126 (Activation  (None, 16, 16, 256)          0         ['conv2d_67[0][0]']
#  )
#
#  batch_normalization_126 (B  (None, 16, 16, 256)          1024      ['activation_126[0][0]']
#  atchNormalization)
#
#  add_209 (Add)               (None, 16, 16, 256)          0         ['add_193[0][0]',
#                                                                      'batch_normalization_126[0][0
#                                                                     ]']
#
#  add_210 (Add)               (None, 16, 16, 256)          0         ['add_151[0][0]',
#                                                                      'add_209[0][0]']
#
#  depthwise_conv2d_63 (Depth  (None, 16, 16, 256)          6656      ['add_210[0][0]']
#  wiseConv2D)
#
#  activation_127 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_63[0][0]']
#  )
#
#  batch_normalization_127 (B  (None, 16, 16, 256)          1024      ['activation_127[0][0]']
#  atchNormalization)
#
#  add_211 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_127[0][0
#                                                                     ]',
#                                                                      'add_210[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 16, 16, 256)          65792     ['add_211[0][0]']
#
#  activation_128 (Activation  (None, 16, 16, 256)          0         ['conv2d_68[0][0]']
#  )
#
#  batch_normalization_128 (B  (None, 16, 16, 256)          1024      ['activation_128[0][0]']
#  atchNormalization)
#
#  add_212 (Add)               (None, 16, 16, 256)          0         ['add_196[0][0]',
#                                                                      'batch_normalization_128[0][0
#                                                                     ]']
#
#  add_213 (Add)               (None, 16, 16, 256)          0         ['add_154[0][0]',
#                                                                      'add_212[0][0]']
#
#  global_average_pooling2d (  (None, 256)                  0         ['add_213[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                    771       ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 5403907 (20.61 MB)
# Trainable params: 5337859 (20.36 MB)
# Non-trainable params: 66048 (258.00 KB)
# __________________________________________________________________________________________________

# %%
history, model = launch_experiment(model)
# Out:
# Epoch 1/20
# 2/2 - 31s - loss: 4414.1792 - mean_squared_error: 4414.1792 - val_loss: 80625.5234 - val_mean_squared_error: 80625.5234 - 31s/epoch - 16s/step
# Epoch 2/20
# 2/2 - 2s - loss: 4126.8940 - mean_squared_error: 4126.8940 - val_loss: 190564.4844 - val_mean_squared_error: 190564.4844 - 2s/epoch - 878ms/step
# Epoch 3/20
# 2/2 - 2s - loss: 3757.7815 - mean_squared_error: 3757.7815 - val_loss: 58493.8945 - val_mean_squared_error: 58493.8945 - 2s/epoch - 855ms/step
# Epoch 4/20
# 2/2 - 2s - loss: 3449.1965 - mean_squared_error: 3449.1965 - val_loss: 34994.6875 - val_mean_squared_error: 34994.6875 - 2s/epoch - 807ms/step
# Epoch 5/20
# 2/2 - 1s - loss: 3290.6880 - mean_squared_error: 3290.6880 - val_loss: 44870.1992 - val_mean_squared_error: 44870.1992 - 1s/epoch - 685ms/step
# Epoch 6/20
# 2/2 - 1s - loss: 2761.8376 - mean_squared_error: 2761.8376 - val_loss: 17649.6016 - val_mean_squared_error: 17649.6016 - 1s/epoch - 748ms/step
# Epoch 7/20
# 2/2 - 1s - loss: 3217.2849 - mean_squared_error: 3217.2849 - val_loss: 72671.1016 - val_mean_squared_error: 72671.1016 - 1s/epoch - 716ms/step
# Epoch 8/20
# 2/2 - 1s - loss: 2654.3809 - mean_squared_error: 2654.3809 - val_loss: 135233.4219 - val_mean_squared_error: 135233.4219 - 1s/epoch - 683ms/step
# Epoch 9/20
# 2/2 - 1s - loss: 2633.3208 - mean_squared_error: 2633.3208 - val_loss: 132505.8281 - val_mean_squared_error: 132505.8281 - 1s/epoch - 678ms/step
# Epoch 10/20
# 2/2 - 1s - loss: 2508.7173 - mean_squared_error: 2508.7173 - val_loss: 186284.1250 - val_mean_squared_error: 186284.1250 - 1s/epoch - 731ms/step
# Epoch 11/20
# 2/2 - 1s - loss: 2164.7200 - mean_squared_error: 2164.7200 - val_loss: 202964.7656 - val_mean_squared_error: 202964.7656 - 1s/epoch - 692ms/step
# Epoch 12/20
# 2/2 - 1s - loss: 2355.6873 - mean_squared_error: 2355.6873 - val_loss: 146756.7656 - val_mean_squared_error: 146756.7656 - 1s/epoch - 703ms/step
# Epoch 13/20
# 2/2 - 1s - loss: 2275.2017 - mean_squared_error: 2275.2017 - val_loss: 90433.2188 - val_mean_squared_error: 90433.2188 - 1s/epoch - 721ms/step
# Epoch 14/20
# 2/2 - 1s - loss: 1933.8060 - mean_squared_error: 1933.8060 - val_loss: 67533.5078 - val_mean_squared_error: 67533.5078 - 1s/epoch - 676ms/step
# Epoch 15/20
# 2/2 - 1s - loss: 1951.9244 - mean_squared_error: 1951.9244 - val_loss: 178941.1875 - val_mean_squared_error: 178941.1875 - 1s/epoch - 681ms/step
# Epoch 16/20
# 2/2 - 1s - loss: 1579.4082 - mean_squared_error: 1579.4082 - val_loss: 303266.1250 - val_mean_squared_error: 303266.1250 - 1s/epoch - 695ms/step
# Epoch 17/20
# 2/2 - 1s - loss: 1660.7858 - mean_squared_error: 1660.7858 - val_loss: 334337.3750 - val_mean_squared_error: 334337.3750 - 1s/epoch - 680ms/step
# Epoch 18/20
# 2/2 - 1s - loss: 1496.5090 - mean_squared_error: 1496.5090 - val_loss: 265830.1562 - val_mean_squared_error: 265830.1562 - 1s/epoch - 685ms/step
# Epoch 19/20
# 2/2 - 1s - loss: 1533.7626 - mean_squared_error: 1533.7626 - val_loss: 218402.0781 - val_mean_squared_error: 218402.0781 - 1s/epoch - 646ms/step
# Epoch 20/20
# 2/2 - 1s - loss: 1414.4442 - mean_squared_error: 1414.4442 - val_loss: 206859.1719 - val_mean_squared_error: 206859.1719 - 1s/epoch - 647ms/step
# 1/1 [==============================] - 0s 149ms/step - loss: 168268.3750 - mean_squared_error: 168268.3750
# Test error: 168268.38

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  465.70315836588543
# MSE:  219175.54433118607
# RMSE:  468.1618783403729
# r2_score:  -2076.2565980166078
# MSLE:  28.59096524593285
# MAPE:  1.499954403993802e+18
# ===== flank_wear results =====
# MAE:  423.4874943033854
# MSE:  212433.68717668045
# RMSE:  460.90529089681803
# r2_score:  -12.258580320727376
# MSLE:  3.512121664343678
# MAPE:  6.366336713103188
# ===== overhang results =====
# MAE:  268.42643513997393
# MSE:  73195.88713985852
# RMSE:  270.54738427835247
# r2_score:  -3627.504552733189
# MSLE:  9.365268064225999
# MAPE:  24.145878228310078
# ===== multi results =====
# MAE:  385.8723626030816
# MSE:  168268.372882575
# RMSE:  399.8715178385144
# r2_score:  -1905.3399103568415
# MSLE:  13.822784991500844
# MAPE:  4.999848013312673e+17
