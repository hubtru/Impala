# %%
# !pip install --upgrade keras==2.15.0
# !pip install --upgrade tensorflow==2.15.0.post1
# !pip install --upgrade scipy==1.11.4
# !pip install tensorflow-addons==0.21.0

# clone Impala repository, refresh folder to see the Imapala repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Impala
# Out:
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.0 requires keras>=3.2.0, but you have keras 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0
# Collecting tensorflow==2.15.0.post1
#   Downloading tensorflow-2.15.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0.post1)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0.post1)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0.post1)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0.post1)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0.post1) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0.post1) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0.post1) (3.2.2)
# Downloading tensorflow-2.15.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.0 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.3 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 3.8 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 3.9 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.0
#     Uninstalling ml-dtypes-0.4.0:
#       Successfully uninstalled ml-dtypes-0.4.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.64 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0.post1 which is incompatible.
# Successfully installed ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0.post1 tensorflow-estimator-2.15.0 wrapt-1.14.1
# Collecting scipy==1.11.4
#   Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy==1.11.4) (1.26.4)
# Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 14.4 MB/s eta 0:00:00
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# Successfully installed scipy-1.11.4
# Collecting tensorflow-addons==0.21.0
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.21.0) (24.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons==0.21.0)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 3.4 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.3.0
#     Uninstalling typeguard-4.3.0:
#       Successfully uninstalled typeguard-4.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.3.1 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3
# Cloning into 'Impala'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 235 (delta 4), reused 31 (delta 4), pack-reused 204 (from 1)
# Receiving objects: 100% (235/235), 1.09 GiB | 28.74 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Updating files: 100% (206/206), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "3"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_spec = 9
in_channel_scal = 9
in_channel_chip = 3
in_channel_work = 3
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_spec = (img_rows, img_cols, in_channel_spec)
input_shape_scal = (img_rows, img_cols, in_channel_scal)
input_shape_chip = (img_rows, img_cols, in_channel_chip)
input_shape_work = (img_rows, img_cols, in_channel_work)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 20

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_tsscw"
exp_name = f"impala3d_v3_hexa_regression"
sub_exp_name = f"base"
model_name = f"{exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"/content/Impala/models/{exp_name}_tool.h5"
model_spec_path = f"/content/Impala/models/{exp_name}_spec.h5"
model_scal_path = f"/content/Impala/models/{exp_name}_scal.h5"
model_chip_path = f"/content/Impala/models/{exp_name}_chip.h5"
model_work_path = f"/content/Impala/models/{exp_name}_work.h5"

# dataset
csv_path = "/content/Impala/dataset/labels_reg_sample.csv"
tool_path = "/content/Impala/dataset/tool"
spec_path = "/content/Impala/dataset/spec"
scal_path = "/content/Impala/dataset/scal"
chip_path = "/content/Impala/dataset/chip"
work_path = "/content/Impala/dataset/work"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")

train_df["scal_x"] = train_df.id.map(lambda id: f"{scal_path}/x/{id}.png")
test_df["scal_x"] = test_df.id.map(lambda id: f"{scal_path}/x/{id}.png")
val_df["scal_x"] = val_df.id.map(lambda id: f"{scal_path}/x/{id}.png")

train_df["scal_y"] = train_df.id.map(lambda id: f"{scal_path}/y/{id}.png")
test_df["scal_y"] = test_df.id.map(lambda id: f"{scal_path}/y/{id}.png")
val_df["scal_y"] = val_df.id.map(lambda id: f"{scal_path}/y/{id}.png")

train_df["scal_z"] = train_df.id.map(lambda id: f"{scal_path}/z/{id}.png")
test_df["scal_z"] = test_df.id.map(lambda id: f"{scal_path}/z/{id}.png")
val_df["scal_z"] = val_df.id.map(lambda id: f"{scal_path}/z/{id}.png")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")

train_df["work"] = train_df.id.map(lambda id: f"{work_path}/{id}.png")
test_df["work"] = test_df.id.map(lambda id: f"{work_path}/{id}.png")
val_df["work"] = val_df.id.map(lambda id: f"{work_path}/{id}.png")
# Out:
# size check train/test/val 14 3 3 20

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))
sns.histplot(train_df["gaps"], ax=ax[0])
sns.histplot(train_df["flank_wear"], ax=ax[1])
sns.histplot(train_df["overhang"], ax=ax[2])
ax[0].set_title("Label Distribution")
ax[1].set_title("Label Distribution")
ax[2].set_title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                         tool  \
# 14   /content/Impala/dataset/tool/T8R3B4.jpg
# 10   /content/Impala/dataset/tool/T6R9B3.jpg
# 0    /content/Impala/dataset/tool/T1R2B1.jpg
# 3   /content/Impala/dataset/tool/T2R13B4.jpg
# 1    /content/Impala/dataset/tool/T1R7B4.jpg
#
#                                         spec_x  \
# 14   /content/Impala/dataset/spec/x/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/x/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/x/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/x/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/x/T1R7B4.jpg
#
#                                         spec_y  \
# 14   /content/Impala/dataset/spec/y/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/y/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/y/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/y/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/y/T1R7B4.jpg
#
#                                         spec_z  \
# 14   /content/Impala/dataset/spec/z/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/z/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/z/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/z/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/z/T1R7B4.jpg
#
#                                         scal_x  \
# 14   /content/Impala/dataset/scal/x/T8R3B4.png
# 10   /content/Impala/dataset/scal/x/T6R9B3.png
# 0    /content/Impala/dataset/scal/x/T1R2B1.png
# 3   /content/Impala/dataset/scal/x/T2R13B4.png
# 1    /content/Impala/dataset/scal/x/T1R7B4.png
#
#                                         scal_y  \
# 14   /content/Impala/dataset/scal/y/T8R3B4.png
# 10   /content/Impala/dataset/scal/y/T6R9B3.png
# 0    /content/Impala/dataset/scal/y/T1R2B1.png
# 3   /content/Impala/dataset/scal/y/T2R13B4.png
# 1    /content/Impala/dataset/scal/y/T1R7B4.png
#
#                                         scal_z  \
# 14   /content/Impala/dataset/scal/z/T8R3B4.png
# 10   /content/Impala/dataset/scal/z/T6R9B3.png
# 0    /content/Impala/dataset/scal/z/T1R2B1.png
# 3   /content/Impala/dataset/scal/z/T2R13B4.png
# 1    /content/Impala/dataset/scal/z/T1R7B4.png
#
#                                         chip  \
# 14   /content/Impala/dataset/chip/T8R3B4.jpg
# 10   /content/Impala/dataset/chip/T6R9B3.jpg
# 0    /content/Impala/dataset/chip/T1R2B1.jpg
# 3   /content/Impala/dataset/chip/T2R13B4.jpg
# 1    /content/Impala/dataset/chip/T1R7B4.jpg
#
#                                         work
# 14   /content/Impala/dataset/work/T8R3B4.png
# 10   /content/Impala/dataset/work/T6R9B3.png
# 0    /content/Impala/dataset/work/T1R2B1.png
# 3   /content/Impala/dataset/work/T2R13B4.png
# 1    /content/Impala/dataset/work/T1R7B4.png
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                         tool  \
# 16   /content/Impala/dataset/tool/T9R7B4.jpg
# 18  /content/Impala/dataset/tool/T10R3B4.jpg
# 9   /content/Impala/dataset/tool/T5R12B1.jpg
#
#                                         spec_x  \
# 16   /content/Impala/dataset/spec/x/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/x/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/x/T5R12B1.jpg
#
#                                         spec_y  \
# 16   /content/Impala/dataset/spec/y/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/y/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/y/T5R12B1.jpg
#
#                                         spec_z  \
# 16   /content/Impala/dataset/spec/z/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/z/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/z/T5R12B1.jpg
#
#                                         scal_x  \
# 16   /content/Impala/dataset/scal/x/T9R7B4.png
# 18  /content/Impala/dataset/scal/x/T10R3B4.png
# 9   /content/Impala/dataset/scal/x/T5R12B1.png
#
#                                         scal_y  \
# 16   /content/Impala/dataset/scal/y/T9R7B4.png
# 18  /content/Impala/dataset/scal/y/T10R3B4.png
# 9   /content/Impala/dataset/scal/y/T5R12B1.png
#
#                                         scal_z  \
# 16   /content/Impala/dataset/scal/z/T9R7B4.png
# 18  /content/Impala/dataset/scal/z/T10R3B4.png
# 9   /content/Impala/dataset/scal/z/T5R12B1.png
#
#                                         chip  \
# 16   /content/Impala/dataset/chip/T9R7B4.jpg
# 18  /content/Impala/dataset/chip/T10R3B4.jpg
# 9   /content/Impala/dataset/chip/T5R12B1.jpg
#
#                                         work
# 16   /content/Impala/dataset/work/T9R7B4.png
# 18  /content/Impala/dataset/work/T10R3B4.png
# 9   /content/Impala/dataset/work/T5R12B1.png
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                         tool  \
# 5   /content/Impala/dataset/tool/T3R10B1.jpg
# 13  /content/Impala/dataset/tool/T7R14B3.jpg
# 12   /content/Impala/dataset/tool/T7R8B3.jpg
#
#                                         spec_x  \
# 5   /content/Impala/dataset/spec/x/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/x/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/x/T7R8B3.jpg
#
#                                         spec_y  \
# 5   /content/Impala/dataset/spec/y/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/y/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/y/T7R8B3.jpg
#
#                                         spec_z  \
# 5   /content/Impala/dataset/spec/z/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/z/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/z/T7R8B3.jpg
#
#                                         scal_x  \
# 5   /content/Impala/dataset/scal/x/T3R10B1.png
# 13  /content/Impala/dataset/scal/x/T7R14B3.png
# 12   /content/Impala/dataset/scal/x/T7R8B3.png
#
#                                         scal_y  \
# 5   /content/Impala/dataset/scal/y/T3R10B1.png
# 13  /content/Impala/dataset/scal/y/T7R14B3.png
# 12   /content/Impala/dataset/scal/y/T7R8B3.png
#
#                                         scal_z  \
# 5   /content/Impala/dataset/scal/z/T3R10B1.png
# 13  /content/Impala/dataset/scal/z/T7R14B3.png
# 12   /content/Impala/dataset/scal/z/T7R8B3.png
#
#                                         chip  \
# 5   /content/Impala/dataset/chip/T3R10B1.jpg
# 13  /content/Impala/dataset/chip/T7R14B3.jpg
# 12   /content/Impala/dataset/chip/T7R8B3.jpg
#
#                                         work
# 5   /content/Impala/dataset/work/T3R10B1.png
# 13  /content/Impala/dataset/work/T7R14B3.png
# 12   /content/Impala/dataset/work/T7R8B3.png

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images


def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []
    for i in range(file_paths_x.size):
        img = []
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_x)

        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_y)

        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_z)
        img = np.concatenate(img, axis=2)
        images.append(img)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)

x_train_scal = read_specs(
    train_df.scal_x.values,
    train_df.scal_y.values,
    train_df.scal_z.values,
    img_rows,
    img_cols,
    in_channel_scal,
)
x_test_scal = read_specs(
    test_df.scal_x.values,
    test_df.scal_y.values,
    test_df.scal_z.values,
    img_rows,
    img_cols,
    in_channel_scal,
)
x_val_scal = read_specs(
    val_df.scal_x.values,
    val_df.scal_y.values,
    val_df.scal_z.values,
    img_rows,
    img_cols,
    in_channel_scal,
)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

x_train_work = read_tools(train_df.work.values, img_rows, img_cols, in_channel_work)
x_test_work = read_tools(test_df.work.values, img_rows, img_cols, in_channel_work)
x_val_work = read_tools(val_df.work.values, img_rows, img_cols, in_channel_work)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
x_train_scal.shape
# Out:
# (14, 256, 256, 9)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_work.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img_tool = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img_spec_x = tf.keras.utils.array_to_img(x_train_spec[0][:,:,:3])
pil_img_spec_y = tf.keras.utils.array_to_img(x_train_spec[0][:,:,3:6])
pil_img_spec_z = tf.keras.utils.array_to_img(x_train_spec[0][:,:,6:9])
pil_img_scal_x = tf.keras.utils.array_to_img(np.flip(x_train_scal[0][:,:,:3],axis=-1))
pil_img_scal_y = tf.keras.utils.array_to_img(np.flip(x_train_scal[0][:,:,3:6],axis=-1))
pil_img_scal_z = tf.keras.utils.array_to_img(np.flip(x_train_scal[0][:,:,6:9],axis=-1))
pil_img_chip = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img_work = tf.keras.utils.array_to_img(x_train_work[0])

fig, ax = plt.subplots(3, 3, figsize=(12, 12))
ax[0][0].imshow(pil_img_tool)
ax[0][1].imshow(pil_img_chip)
ax[0][2].imshow(pil_img_work)
ax[1][0].imshow(pil_img_spec_x)
ax[1][1].imshow(pil_img_spec_y)
ax[1][2].imshow(pil_img_spec_z)
ax[2][0].imshow(pil_img_scal_x)
ax[2][1].imshow(pil_img_scal_y)
ax[2][2].imshow(pil_img_scal_z)
ax[0][0].set_title("tool")
ax[0][1].set_title("chip")
ax[0][2].set_title("work")
ax[1][0].set_title("spec_x")
ax[1][1].set_title("spec_y")
ax[1][2].set_title("spec_z")
ax[2][0].set_title("scal_x")
ax[2][1].set_title("scal_y")
ax[2][2].set_title("scal_z")
plt.show()

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
# ============================== augment 1/5 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)

# %%
# ============================== augment 2/5 ==============================
data_augmentation_spec = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_spec",
)

# %%
# ============================== augment 3/5 ==============================
data_augmentation_scal = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_scal",
)

# %%
# ============================== augment 4/5 ==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
# ============================== augment 5/5 ==============================
data_augmentation_work = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_work",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_spec = data_augmentation_spec(x_train_spec)
x_train_scal = data_augmentation_scal(x_train_scal)
x_train_chip = data_augmentation_chip(x_train_chip)
x_train_work = data_augmentation_work(x_train_work)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_spec": x_train_spec,
            "input_1_scal": x_train_scal,
            "input_1_chip": x_train_chip,
            "input_1_work": x_train_work,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_spec": x_test_spec,
            "input_1_scal": x_test_scal,
            "input_1_chip": x_test_chip,
            "input_1_work": x_test_work,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_spec": x_val_spec,
            "input_1_scal": x_val_scal,
            "input_1_chip": x_val_chip,
            "input_1_work": x_val_work,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs2 = k.Input(input_shape_spec)
inputs3 = k.Input(input_shape_scal)
inputs4 = k.Input(input_shape_chip)
inputs5 = k.Input(input_shape_work)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_spec': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), 'input_1_scal': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_work': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
# ============================== build/load model(s) ==============================
model_tool = k.models.load_model(model_tool_path, compile=False)
model_spec = k.models.load_model(model_spec_path, compile=False)
model_scal = k.models.load_model(model_scal_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)
model_work = k.models.load_model(model_work_path, compile=False)

model_tool.trainable = False
model_spec.trainable = False
model_scal.trainable = False
model_chip.trainable = False
model_work.trainable = False

def multimodal_conv_build(model_tool, model_spec, model_scal, model_chip, model_work):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs2 = model_spec.input
    inputs2._name = "input_spec"
    inputs3 = model_scal.input
    inputs3._name = "input_scal"
    inputs4 = model_chip.input
    inputs4._name = "input_chip"
    inputs5 = model_work.input
    inputs5._name = "input_work"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_spec = k.Model(
        inputs=model_spec.input, outputs=model_spec.layers[-2].output
    )
    truncated_model_scal = k.Model(
        inputs=model_scal.input, outputs=model_scal.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    truncated_model_work = k.Model(
        inputs=model_work.input, outputs=model_work.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_spec.output,
            truncated_model_scal.output,
            truncated_model_chip.output,
            truncated_model_work.output,
        ]
    )
    output = layers.Dense(num_classes, activation="linear", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs2, inputs3, inputs4, inputs5], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_spec.layers:
    layer._name = layer.name + str("_spec")
for layer in model_scal.layers:
    layer._name = layer.name + str("_scal")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")
for layer in model_work.layers:
    layer._name = layer.name + str("_work")

# %%
# ============================== run experiment ==============================
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        verbose=2,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = multimodal_conv_build(model_tool, model_spec, model_scal, model_chip, model_work)
model.summary()
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#
#  add_86_tool (Add)           (None, 16, 16, 256)          0         ['add_70_tool[0][0]',
#                                                                      'batch_normalization_60_tool[
#                                                                     0][0]']
#
#  add_77_spec (Add)           (None, 16, 16, 256)          0         ['add_61_spec[0][0]',
#                                                                      'batch_normalization_56_spec[
#                                                                     0][0]']
#
#  add_86_spec (Add)           (None, 16, 16, 256)          0         ['add_70_spec[0][0]',
#                                                                      'batch_normalization_60_spec[
#                                                                     0][0]']
#
#  add_77_scal (Add)           (None, 16, 16, 256)          0         ['add_61_scal[0][0]',
#                                                                      'batch_normalization_56_scal[
#                                                                     0][0]']
#
#  add_86_scal (Add)           (None, 16, 16, 256)          0         ['add_70_scal[0][0]',
#                                                                      'batch_normalization_60_scal[
#                                                                     0][0]']
#
#  add_77_chip (Add)           (None, 16, 16, 256)          0         ['add_61_chip[0][0]',
#                                                                      'batch_normalization_56_chip[
#                                                                     0][0]']
#
#  add_86_chip (Add)           (None, 16, 16, 256)          0         ['add_70_chip[0][0]',
#                                                                      'batch_normalization_60_chip[
#                                                                     0][0]']
#
#  add_77_work (Add)           (None, 16, 16, 256)          0         ['add_61_work[0][0]',
#                                                                      'batch_normalization_56_work[
#                                                                     0][0]']
#
#  add_86_work (Add)           (None, 16, 16, 256)          0         ['add_70_work[0][0]',
#                                                                      'batch_normalization_60_work[
#                                                                     0][0]']
#
#  add_78_tool (Add)           (None, 16, 16, 256)          0         ['add_25_tool[0][0]',
#                                                                      'add_77_tool[0][0]']
#
#  add_87_tool (Add)           (None, 16, 16, 256)          0         ['add_31_tool[0][0]',
#                                                                      'add_86_tool[0][0]']
#
#  add_78_spec (Add)           (None, 16, 16, 256)          0         ['add_25_spec[0][0]',
#                                                                      'add_77_spec[0][0]']
#
#  add_87_spec (Add)           (None, 16, 16, 256)          0         ['add_31_spec[0][0]',
#                                                                      'add_86_spec[0][0]']
#
#  add_78_scal (Add)           (None, 16, 16, 256)          0         ['add_25_scal[0][0]',
#                                                                      'add_77_scal[0][0]']
#
#  add_87_scal (Add)           (None, 16, 16, 256)          0         ['add_31_scal[0][0]',
#                                                                      'add_86_scal[0][0]']
#
#  add_78_chip (Add)           (None, 16, 16, 256)          0         ['add_25_chip[0][0]',
#                                                                      'add_77_chip[0][0]']
#
#  add_87_chip (Add)           (None, 16, 16, 256)          0         ['add_31_chip[0][0]',
#                                                                      'add_86_chip[0][0]']
#
#  add_78_work (Add)           (None, 16, 16, 256)          0         ['add_25_work[0][0]',
#                                                                      'add_77_work[0][0]']
#
#  add_87_work (Add)           (None, 16, 16, 256)          0         ['add_31_work[0][0]',
#                                                                      'add_86_work[0][0]']
#
#  add_88_tool (Add)           (None, 16, 16, 256)          0         ['add_78_tool[0][0]',
#                                                                      'add_87_tool[0][0]']
#
#  add_88_spec (Add)           (None, 16, 16, 256)          0         ['add_78_spec[0][0]',
#                                                                      'add_87_spec[0][0]']
#
#  add_88_scal (Add)           (None, 16, 16, 256)          0         ['add_78_scal[0][0]',
#                                                                      'add_87_scal[0][0]']
#
#  add_88_chip (Add)           (None, 16, 16, 256)          0         ['add_78_chip[0][0]',
#                                                                      'add_87_chip[0][0]']
#
#  add_88_work (Add)           (None, 16, 16, 256)          0         ['add_78_work[0][0]',
#                                                                      'add_87_work[0][0]']
#
#  depthwise_conv2d_30_tool (  (None, 16, 16, 256)          6656      ['add_88_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_30_spec (  (None, 16, 16, 256)          6656      ['add_88_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_30_scal (  (None, 16, 16, 256)          6656      ['add_88_scal[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_30_chip (  (None, 16, 16, 256)          6656      ['add_88_chip[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_30_work (  (None, 16, 16, 256)          6656      ['add_88_work[0][0]']
#  DepthwiseConv2D)
#
#  activation_61_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_30_tool[0][
#  tion)                                                              0]']
#
#  activation_61_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_30_spec[0][
#  tion)                                                              0]']
#
#  activation_61_scal (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_30_scal[0][
#  tion)                                                              0]']
#
#  activation_61_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_30_chip[0][
#  tion)                                                              0]']
#
#  activation_61_work (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_30_work[0][
#  tion)                                                              0]']
#
#  batch_normalization_61_too  (None, 16, 16, 256)          1024      ['activation_61_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_61_spe  (None, 16, 16, 256)          1024      ['activation_61_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_61_sca  (None, 16, 16, 256)          1024      ['activation_61_scal[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_61_chi  (None, 16, 16, 256)          1024      ['activation_61_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_61_wor  (None, 16, 16, 256)          1024      ['activation_61_work[0][0]']
#  k (BatchNormalization)
#
#  add_90_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_61_tool[
#                                                                     0][0]',
#                                                                      'add_88_tool[0][0]']
#
#  add_90_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_61_spec[
#                                                                     0][0]',
#                                                                      'add_88_spec[0][0]']
#
#  add_90_scal (Add)           (None, 16, 16, 256)          0         ['batch_normalization_61_scal[
#                                                                     0][0]',
#                                                                      'add_88_scal[0][0]']
#
#  add_90_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_61_chip[
#                                                                     0][0]',
#                                                                      'add_88_chip[0][0]']
#
#  add_90_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_61_work[
#                                                                     0][0]',
#                                                                      'add_88_work[0][0]']
#
#  conv2d_31_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_90_tool[0][0]']
#
#  conv2d_31_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_90_spec[0][0]']
#
#  conv2d_31_scal (Conv2D)     (None, 16, 16, 256)          65792     ['add_90_scal[0][0]']
#
#  conv2d_31_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_90_chip[0][0]']
#
#  conv2d_31_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_90_work[0][0]']
#
#  activation_62_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_31_tool[0][0]']
#  tion)
#
#  activation_62_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_31_spec[0][0]']
#  tion)
#
#  activation_62_scal (Activa  (None, 16, 16, 256)          0         ['conv2d_31_scal[0][0]']
#  tion)
#
#  activation_62_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_31_chip[0][0]']
#  tion)
#
#  activation_62_work (Activa  (None, 16, 16, 256)          0         ['conv2d_31_work[0][0]']
#  tion)
#
#  batch_normalization_62_too  (None, 16, 16, 256)          1024      ['activation_62_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_62_spe  (None, 16, 16, 256)          1024      ['activation_62_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_62_sca  (None, 16, 16, 256)          1024      ['activation_62_scal[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_62_chi  (None, 16, 16, 256)          1024      ['activation_62_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_62_wor  (None, 16, 16, 256)          1024      ['activation_62_work[0][0]']
#  k (BatchNormalization)
#
#  add_91_tool (Add)           (None, 16, 16, 256)          0         ['add_75_tool[0][0]',
#                                                                      'batch_normalization_62_tool[
#                                                                     0][0]']
#
#  add_91_spec (Add)           (None, 16, 16, 256)          0         ['add_75_spec[0][0]',
#                                                                      'batch_normalization_62_spec[
#                                                                     0][0]']
#
#  add_91_scal (Add)           (None, 16, 16, 256)          0         ['add_75_scal[0][0]',
#                                                                      'batch_normalization_62_scal[
#                                                                     0][0]']
#
#  add_91_chip (Add)           (None, 16, 16, 256)          0         ['add_75_chip[0][0]',
#                                                                      'batch_normalization_62_chip[
#                                                                     0][0]']
#
#  add_91_work (Add)           (None, 16, 16, 256)          0         ['add_75_work[0][0]',
#                                                                      'batch_normalization_62_work[
#                                                                     0][0]']
#
#  add_92_tool (Add)           (None, 16, 16, 256)          0         ['add_34_tool[0][0]',
#                                                                      'add_91_tool[0][0]']
#
#  add_92_spec (Add)           (None, 16, 16, 256)          0         ['add_34_spec[0][0]',
#                                                                      'add_91_spec[0][0]']
#
#  add_92_scal (Add)           (None, 16, 16, 256)          0         ['add_34_scal[0][0]',
#                                                                      'add_91_scal[0][0]']
#
#  add_92_chip (Add)           (None, 16, 16, 256)          0         ['add_34_chip[0][0]',
#                                                                      'add_91_chip[0][0]']
#
#  add_92_work (Add)           (None, 16, 16, 256)          0         ['add_34_work[0][0]',
#                                                                      'add_91_work[0][0]']
#
#  depthwise_conv2d_31_tool (  (None, 16, 16, 256)          6656      ['add_92_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_31_spec (  (None, 16, 16, 256)          6656      ['add_92_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_31_scal (  (None, 16, 16, 256)          6656      ['add_92_scal[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_31_chip (  (None, 16, 16, 256)          6656      ['add_92_chip[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_31_work (  (None, 16, 16, 256)          6656      ['add_92_work[0][0]']
#  DepthwiseConv2D)
#
#  activation_63_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_31_tool[0][
#  tion)                                                              0]']
#
#  activation_63_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_31_spec[0][
#  tion)                                                              0]']
#
#  activation_63_scal (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_31_scal[0][
#  tion)                                                              0]']
#
#  activation_63_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_31_chip[0][
#  tion)                                                              0]']
#
#  activation_63_work (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_31_work[0][
#  tion)                                                              0]']
#
#  batch_normalization_63_too  (None, 16, 16, 256)          1024      ['activation_63_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_63_spe  (None, 16, 16, 256)          1024      ['activation_63_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_63_sca  (None, 16, 16, 256)          1024      ['activation_63_scal[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_63_chi  (None, 16, 16, 256)          1024      ['activation_63_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_63_wor  (None, 16, 16, 256)          1024      ['activation_63_work[0][0]']
#  k (BatchNormalization)
#
#  add_93_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_63_tool[
#                                                                     0][0]',
#                                                                      'add_92_tool[0][0]']
#
#  add_93_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_63_spec[
#                                                                     0][0]',
#                                                                      'add_92_spec[0][0]']
#
#  add_93_scal (Add)           (None, 16, 16, 256)          0         ['batch_normalization_63_scal[
#                                                                     0][0]',
#                                                                      'add_92_scal[0][0]']
#
#  add_93_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_63_chip[
#                                                                     0][0]',
#                                                                      'add_92_chip[0][0]']
#
#  add_93_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_63_work[
#                                                                     0][0]',
#                                                                      'add_92_work[0][0]']
#
#  conv2d_32_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_93_tool[0][0]']
#
#  conv2d_32_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_93_spec[0][0]']
#
#  conv2d_32_scal (Conv2D)     (None, 16, 16, 256)          65792     ['add_93_scal[0][0]']
#
#  conv2d_32_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_93_chip[0][0]']
#
#  conv2d_32_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_93_work[0][0]']
#
#  activation_64_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_32_tool[0][0]']
#  tion)
#
#  activation_64_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_32_spec[0][0]']
#  tion)
#
#  activation_64_scal (Activa  (None, 16, 16, 256)          0         ['conv2d_32_scal[0][0]']
#  tion)
#
#  activation_64_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_32_chip[0][0]']
#  tion)
#
#  activation_64_work (Activa  (None, 16, 16, 256)          0         ['conv2d_32_work[0][0]']
#  tion)
#
#  batch_normalization_64_too  (None, 16, 16, 256)          1024      ['activation_64_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_64_spe  (None, 16, 16, 256)          1024      ['activation_64_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_64_sca  (None, 16, 16, 256)          1024      ['activation_64_scal[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_64_chi  (None, 16, 16, 256)          1024      ['activation_64_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_64_wor  (None, 16, 16, 256)          1024      ['activation_64_work[0][0]']
#  k (BatchNormalization)
#
#  add_94_tool (Add)           (None, 16, 16, 256)          0         ['add_78_tool[0][0]',
#                                                                      'batch_normalization_64_tool[
#                                                                     0][0]']
#
#  add_94_spec (Add)           (None, 16, 16, 256)          0         ['add_78_spec[0][0]',
#                                                                      'batch_normalization_64_spec[
#                                                                     0][0]']
#
#  add_94_scal (Add)           (None, 16, 16, 256)          0         ['add_78_scal[0][0]',
#                                                                      'batch_normalization_64_scal[
#                                                                     0][0]']
#
#  add_94_chip (Add)           (None, 16, 16, 256)          0         ['add_78_chip[0][0]',
#                                                                      'batch_normalization_64_chip[
#                                                                     0][0]']
#
#  add_94_work (Add)           (None, 16, 16, 256)          0         ['add_78_work[0][0]',
#                                                                      'batch_normalization_64_work[
#                                                                     0][0]']
#
#  add_95_tool (Add)           (None, 16, 16, 256)          0         ['add_36_tool[0][0]',
#                                                                      'add_94_tool[0][0]']
#
#  add_95_spec (Add)           (None, 16, 16, 256)          0         ['add_36_spec[0][0]',
#                                                                      'add_94_spec[0][0]']
#
#  add_95_scal (Add)           (None, 16, 16, 256)          0         ['add_36_scal[0][0]',
#                                                                      'add_94_scal[0][0]']
#
#  add_95_chip (Add)           (None, 16, 16, 256)          0         ['add_36_chip[0][0]',
#                                                                      'add_94_chip[0][0]']
#
#  add_95_work (Add)           (None, 16, 16, 256)          0         ['add_36_work[0][0]',
#                                                                      'add_94_work[0][0]']
#
#  depthwise_conv2d_32_tool (  (None, 16, 16, 256)          6656      ['add_95_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_32_spec (  (None, 16, 16, 256)          6656      ['add_95_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_32_scal (  (None, 16, 16, 256)          6656      ['add_95_scal[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_32_chip (  (None, 16, 16, 256)          6656      ['add_95_chip[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_32_work (  (None, 16, 16, 256)          6656      ['add_95_work[0][0]']
#  DepthwiseConv2D)
#
#  activation_65_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_32_tool[0][
#  tion)                                                              0]']
#
#  activation_65_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_32_spec[0][
#  tion)                                                              0]']
#
#  activation_65_scal (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_32_scal[0][
#  tion)                                                              0]']
#
#  activation_65_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_32_chip[0][
#  tion)                                                              0]']
#
#  activation_65_work (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_32_work[0][
#  tion)                                                              0]']
#
#  batch_normalization_65_too  (None, 16, 16, 256)          1024      ['activation_65_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_65_spe  (None, 16, 16, 256)          1024      ['activation_65_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_65_sca  (None, 16, 16, 256)          1024      ['activation_65_scal[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_65_chi  (None, 16, 16, 256)          1024      ['activation_65_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_65_wor  (None, 16, 16, 256)          1024      ['activation_65_work[0][0]']
#  k (BatchNormalization)
#
#  add_96_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_65_tool[
#                                                                     0][0]',
#                                                                      'add_95_tool[0][0]']
#
#  add_96_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_65_spec[
#                                                                     0][0]',
#                                                                      'add_95_spec[0][0]']
#
#  add_96_scal (Add)           (None, 16, 16, 256)          0         ['batch_normalization_65_scal[
#                                                                     0][0]',
#                                                                      'add_95_scal[0][0]']
#
#  add_96_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_65_chip[
#                                                                     0][0]',
#                                                                      'add_95_chip[0][0]']
#
#  add_96_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_65_work[
#                                                                     0][0]',
#                                                                      'add_95_work[0][0]']
#
#  conv2d_33_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_96_tool[0][0]']
#
#  conv2d_33_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_96_spec[0][0]']
#
#  conv2d_33_scal (Conv2D)     (None, 16, 16, 256)          65792     ['add_96_scal[0][0]']
#
#  conv2d_33_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_96_chip[0][0]']
#
#  conv2d_33_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_96_work[0][0]']
#
#  activation_66_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_33_tool[0][0]']
#  tion)
#
#  activation_66_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_33_spec[0][0]']
#  tion)
#
#  activation_66_scal (Activa  (None, 16, 16, 256)          0         ['conv2d_33_scal[0][0]']
#  tion)
#
#  activation_66_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_33_chip[0][0]']
#  tion)
#
#  activation_66_work (Activa  (None, 16, 16, 256)          0         ['conv2d_33_work[0][0]']
#  tion)
#
#  batch_normalization_66_too  (None, 16, 16, 256)          1024      ['activation_66_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_66_spe  (None, 16, 16, 256)          1024      ['activation_66_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_66_sca  (None, 16, 16, 256)          1024      ['activation_66_scal[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_66_chi  (None, 16, 16, 256)          1024      ['activation_66_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_66_wor  (None, 16, 16, 256)          1024      ['activation_66_work[0][0]']
#  k (BatchNormalization)
#
#  depthwise_conv2d_33_tool (  (None, 16, 16, 256)          6656      ['batch_normalization_66_tool[
#  DepthwiseConv2D)                                                   0][0]']
#
#  depthwise_conv2d_33_spec (  (None, 16, 16, 256)          6656      ['batch_normalization_66_spec[
#  DepthwiseConv2D)                                                   0][0]']
#
#  depthwise_conv2d_33_scal (  (None, 16, 16, 256)          6656      ['batch_normalization_66_scal[
#  DepthwiseConv2D)                                                   0][0]']
#
#  depthwise_conv2d_33_chip (  (None, 16, 16, 256)          6656      ['batch_normalization_66_chip[
#  DepthwiseConv2D)                                                   0][0]']
#
#  depthwise_conv2d_33_work (  (None, 16, 16, 256)          6656      ['batch_normalization_66_work[
#  DepthwiseConv2D)                                                   0][0]']
#
#  activation_67_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_33_tool[0][
#  tion)                                                              0]']
# ...
#  activation_127_tool (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_tool[0][
#  ation)                                                             0]']
#
#  activation_127_spec (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_spec[0][
#  ation)                                                             0]']
#
#  activation_127_scal (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_scal[0][
#  ation)                                                             0]']
#
#  activation_127_chip (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_chip[0][
#  ation)                                                             0]']
#
#  activation_127_work (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_work[0][
#  ation)                                                             0]']
#
#  batch_normalization_127_to  (None, 16, 16, 256)          1024      ['activation_127_tool[0][0]']
#  ol (BatchNormalization)
#
#  batch_normalization_127_sp  (None, 16, 16, 256)          1024      ['activation_127_spec[0][0]']
#  ec (BatchNormalization)
#
#  batch_normalization_127_sc  (None, 16, 16, 256)          1024      ['activation_127_scal[0][0]']
#  al (BatchNormalization)
#
#  batch_normalization_127_ch  (None, 16, 16, 256)          1024      ['activation_127_chip[0][0]']
#  ip (BatchNormalization)
#
#  batch_normalization_127_wo  (None, 16, 16, 256)          1024      ['activation_127_work[0][0]']
#  rk (BatchNormalization)
#
#  add_211_tool (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_tool
#                                                                     [0][0]',
#                                                                      'add_210_tool[0][0]']
#
#  add_211_spec (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_spec
#                                                                     [0][0]',
#                                                                      'add_210_spec[0][0]']
#
#  add_211_scal (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_scal
#                                                                     [0][0]',
#                                                                      'add_210_scal[0][0]']
#
#  add_211_chip (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_chip
#                                                                     [0][0]',
#                                                                      'add_210_chip[0][0]']
#
#  add_211_work (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_work
#                                                                     [0][0]',
#                                                                      'add_210_work[0][0]']
#
#  conv2d_64_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_tool[0][0]']
#
#  conv2d_64_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_spec[0][0]']
#
#  conv2d_64_scal (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_scal[0][0]']
#
#  conv2d_64_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_chip[0][0]']
#
#  conv2d_64_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_work[0][0]']
#
#  activation_128_tool (Activ  (None, 16, 16, 256)          0         ['conv2d_64_tool[0][0]']
#  ation)
#
#  activation_128_spec (Activ  (None, 16, 16, 256)          0         ['conv2d_64_spec[0][0]']
#  ation)
#
#  activation_128_scal (Activ  (None, 16, 16, 256)          0         ['conv2d_64_scal[0][0]']
#  ation)
#
#  activation_128_chip (Activ  (None, 16, 16, 256)          0         ['conv2d_64_chip[0][0]']
#  ation)
#
#  activation_128_work (Activ  (None, 16, 16, 256)          0         ['conv2d_64_work[0][0]']
#  ation)
#
#  batch_normalization_128_to  (None, 16, 16, 256)          1024      ['activation_128_tool[0][0]']
#  ol (BatchNormalization)
#
#  batch_normalization_128_sp  (None, 16, 16, 256)          1024      ['activation_128_spec[0][0]']
#  ec (BatchNormalization)
#
#  batch_normalization_128_sc  (None, 16, 16, 256)          1024      ['activation_128_scal[0][0]']
#  al (BatchNormalization)
#
#  batch_normalization_128_ch  (None, 16, 16, 256)          1024      ['activation_128_chip[0][0]']
#  ip (BatchNormalization)
#
#  batch_normalization_128_wo  (None, 16, 16, 256)          1024      ['activation_128_work[0][0]']
#  rk (BatchNormalization)
#
#  add_212_tool (Add)          (None, 16, 16, 256)          0         ['add_196_tool[0][0]',
#                                                                      'batch_normalization_128_tool
#                                                                     [0][0]']
#
#  add_212_spec (Add)          (None, 16, 16, 256)          0         ['add_196_spec[0][0]',
#                                                                      'batch_normalization_128_spec
#                                                                     [0][0]']
#
#  add_212_scal (Add)          (None, 16, 16, 256)          0         ['add_196_scal[0][0]',
#                                                                      'batch_normalization_128_scal
#                                                                     [0][0]']
#
#  add_212_chip (Add)          (None, 16, 16, 256)          0         ['add_196_chip[0][0]',
#                                                                      'batch_normalization_128_chip
#                                                                     [0][0]']
#
#  add_212_work (Add)          (None, 16, 16, 256)          0         ['add_196_work[0][0]',
#                                                                      'batch_normalization_128_work
#                                                                     [0][0]']
#
#  add_213_tool (Add)          (None, 16, 16, 256)          0         ['add_154_tool[0][0]',
#                                                                      'add_212_tool[0][0]']
#
#  add_213_spec (Add)          (None, 16, 16, 256)          0         ['add_154_spec[0][0]',
#                                                                      'add_212_spec[0][0]']
#
#  add_213_scal (Add)          (None, 16, 16, 256)          0         ['add_154_scal[0][0]',
#                                                                      'add_212_scal[0][0]']
#
#  add_213_chip (Add)          (None, 16, 16, 256)          0         ['add_154_chip[0][0]',
#                                                                      'add_212_chip[0][0]']
#
#  add_213_work (Add)          (None, 16, 16, 256)          0         ['add_154_work[0][0]',
#                                                                      'add_212_work[0][0]']
#
#  global_average_pooling2d_t  (None, 256)                  0         ['add_213_tool[0][0]']
#  ool (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_s  (None, 256)                  0         ['add_213_spec[0][0]']
#  pec (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_s  (None, 256)                  0         ['add_213_scal[0][0]']
#  cal (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_c  (None, 256)                  0         ['add_213_chip[0][0]']
#  hip (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_w  (None, 256)                  0         ['add_213_work[0][0]']
#  ork (GlobalAveragePooling2
#  D)
#
#  concatenate_1 (Concatenate  (None, 1280)                 0         ['global_average_pooling2d_too
#  )                                                                  l[0][0]',
#                                                                      'global_average_pooling2d_spe
#                                                                     c[0][0]',
#                                                                      'global_average_pooling2d_sca
#                                                                     l[0][0]',
#                                                                      'global_average_pooling2d_chi
#                                                                     p[0][0]',
#                                                                      'global_average_pooling2d_wor
#                                                                     k[0][0]']
#
#  output_mult (Dense)         (None, 3)                    3843      ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 25618435 (97.73 MB)
# Trainable params: 3843 (15.01 KB)
# Non-trainable params: 25614592 (97.71 MB)
# __________________________________________________________________________________________________

# %%
history, model = run_experiment(model)
# Out:
# Epoch 1/20
# 2/2 - 127s - loss: 3743.3923 - mean_squared_error: 3743.3923 - val_loss: 4080.8533 - val_mean_squared_error: 4080.8533 - 127s/epoch - 63s/step
# Epoch 2/20
# 2/2 - 6s - loss: 2979.3416 - mean_squared_error: 2979.3416 - val_loss: 3325.5527 - val_mean_squared_error: 3325.5527 - 6s/epoch - 3s/step
# Epoch 3/20
# 2/2 - 6s - loss: 2429.4341 - mean_squared_error: 2429.4341 - val_loss: 2682.9958 - val_mean_squared_error: 2682.9958 - 6s/epoch - 3s/step
# Epoch 4/20
# 2/2 - 6s - loss: 1918.8186 - mean_squared_error: 1918.8186 - val_loss: 2105.2605 - val_mean_squared_error: 2105.2605 - 6s/epoch - 3s/step
# Epoch 5/20
# 2/2 - 6s - loss: 1424.8948 - mean_squared_error: 1424.8948 - val_loss: 1598.0184 - val_mean_squared_error: 1598.0184 - 6s/epoch - 3s/step
# Epoch 6/20
# 2/2 - 6s - loss: 1078.7214 - mean_squared_error: 1078.7214 - val_loss: 1180.2125 - val_mean_squared_error: 1180.2125 - 6s/epoch - 3s/step
# Epoch 7/20
# 2/2 - 6s - loss: 818.4494 - mean_squared_error: 818.4494 - val_loss: 852.9478 - val_mean_squared_error: 852.9478 - 6s/epoch - 3s/step
# Epoch 8/20
# 2/2 - 6s - loss: 585.0674 - mean_squared_error: 585.0674 - val_loss: 598.0773 - val_mean_squared_error: 598.0773 - 6s/epoch - 3s/step
# Epoch 9/20
# 2/2 - 6s - loss: 427.1021 - mean_squared_error: 427.1021 - val_loss: 406.2433 - val_mean_squared_error: 406.2433 - 6s/epoch - 3s/step
# Epoch 10/20
# 2/2 - 6s - loss: 319.4297 - mean_squared_error: 319.4297 - val_loss: 269.4060 - val_mean_squared_error: 269.4060 - 6s/epoch - 3s/step
# Epoch 11/20
# 2/2 - 6s - loss: 264.5605 - mean_squared_error: 264.5605 - val_loss: 182.7966 - val_mean_squared_error: 182.7966 - 6s/epoch - 3s/step
# Epoch 12/20
# 2/2 - 6s - loss: 238.6804 - mean_squared_error: 238.6804 - val_loss: 134.9430 - val_mean_squared_error: 134.9430 - 6s/epoch - 3s/step
# Epoch 13/20
# 2/2 - 6s - loss: 221.2619 - mean_squared_error: 221.2619 - val_loss: 110.4244 - val_mean_squared_error: 110.4244 - 6s/epoch - 3s/step
# Epoch 14/20
# 2/2 - 6s - loss: 229.0013 - mean_squared_error: 229.0013 - val_loss: 100.8379 - val_mean_squared_error: 100.8379 - 6s/epoch - 3s/step
# Epoch 15/20
# 2/2 - 6s - loss: 231.6214 - mean_squared_error: 231.6214 - val_loss: 97.7414 - val_mean_squared_error: 97.7414 - 6s/epoch - 3s/step
# Epoch 16/20
# 2/2 - 7s - loss: 235.4517 - mean_squared_error: 235.4517 - val_loss: 98.4692 - val_mean_squared_error: 98.4692 - 7s/epoch - 4s/step
# Epoch 17/20
# 2/2 - 5s - loss: 237.0426 - mean_squared_error: 237.0426 - val_loss: 99.6855 - val_mean_squared_error: 99.6855 - 5s/epoch - 3s/step
# Epoch 18/20
# 2/2 - 6s - loss: 232.2967 - mean_squared_error: 232.2967 - val_loss: 98.8498 - val_mean_squared_error: 98.8498 - 6s/epoch - 3s/step
# Epoch 19/20
# 2/2 - 6s - loss: 220.9271 - mean_squared_error: 220.9271 - val_loss: 96.6868 - val_mean_squared_error: 96.6868 - 6s/epoch - 3s/step
# Epoch 20/20
# 2/2 - 6s - loss: 210.8041 - mean_squared_error: 210.8041 - val_loss: 93.3909 - val_mean_squared_error: 93.3909 - 6s/epoch - 3s/step
# 1/1 [==============================] - 1s 1s/step - loss: 849.7515 - mean_squared_error: 849.7515
# Test error: 849.75

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 20s 20s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  16.03107530593872
# MSE:  349.1407328054497
# RMSE:  18.68530793980794
# r2_score:  -2.309013754566407
# MSLE:  3.833670188826643
# MAPE:  2.807183967466291e+16
# ===== flank_wear results =====
# MAE:  40.20700764973958
# MSE:  2140.107911835548
# RMSE:  46.261300369050886
# r2_score:  0.8664298820907038
# MSLE:  0.15824875433752947
# MAPE:  0.4155877782975657
# ===== overhang results =====
# MAE:  6.213846600850424
# MSE:  60.00509018027169
# RMSE:  7.746295255170157
# r2_score:  -1.9746035114002756
# MSLE:  0.30518226284712086
# MAPE:  0.6980799576151462
# ===== multi results =====
# MAE:  20.81730985217624
# MSE:  849.751244940423
# RMSE:  24.230967854676326
# r2_score:  -1.1390624612919928
# MSLE:  1.432367068670431
# MAPE:  9357279891554304.0
