# %%
# !pip install tensorflow_addons

# clone Impala repository, refresh folder to see the Imapala repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Impala
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Cloning into 'Impala'...
# remote: Enumerating objects: 216, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 216 (delta 1), reused 10 (delta 0), pack-reused 204
# Receiving objects: 100% (216/216), 579.05 MiB | 33.91 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Updating files: 100% (196/196), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
image_size = 256
num_classes = 3

in_channel_tool = 3
in_channel_spec = 9
in_channel_chip = 3
in_channel_work = 3
img_rows, img_cols = image_size, image_size
input_shape_tool = (img_rows, img_cols, in_channel_tool)
input_shape_spec = (img_rows, img_cols, in_channel_spec)
input_shape_chip = (img_rows, img_cols, in_channel_chip)
input_shape_work = (img_rows, img_cols, in_channel_work)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 20

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "multi_tscw"
exp_name = f"impala3d_v3_hexa"
sub_exp_name = f"base"
model_name = f"{exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

model_tool_path = f"/content/Impala/models/{exp_name}_{sub_exp_name}_tool.h5"
model_spec_path = f"/content/Impala/models/{exp_name}_{sub_exp_name}_spec.h5"
model_chip_path = f"/content/Impala/models/{exp_name}_{sub_exp_name}_chip.h5"
model_work_path = f"/content/Impala/models/{exp_name}_{sub_exp_name}_work.h5"

# dataset
csv_path = "/content/Impala/dataset/labels_sample.csv"
tool_path = "/content/Impala/dataset/tool"
spec_path = "/content/Impala/dataset/spec"
chip_path = "/content/Impala/dataset/chip"
work_path = "/content/Impala/dataset/work"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chip/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["tool"] = train_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
test_df["tool"] = test_df.id.map(lambda id: f"{tool_path}/{id}.jpg")
val_df["tool"] = val_df.id.map(lambda id: f"{tool_path}/{id}.jpg")

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")

train_df["chip"] = train_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
test_df["chip"] = test_df.id.map(lambda id: f"{chip_path}/{id}.jpg")
val_df["chip"] = val_df.id.map(lambda id: f"{chip_path}/{id}.jpg")

train_df["work"] = train_df.id.map(lambda id: f"{work_path}/{id}.png")
test_df["work"] = test_df.id.map(lambda id: f"{work_path}/{id}.png")
val_df["work"] = val_df.id.map(lambda id: f"{work_path}/{id}.png")
# Out:
# size check train/test/val 14 3 3 20

# %%
plt.figure(figsize=(6, 6))
sns.displot(train_df["tool_label"])
plt.title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id image_label  tool_label                                      tool  \
# 14   T8R3B4       sharp           1   /content/Impala/dataset/tool/T8R3B4.jpg
# 10   T6R9B3        used           2   /content/Impala/dataset/tool/T6R9B3.jpg
# 0    T1R2B1       sharp           1   /content/Impala/dataset/tool/T1R2B1.jpg
# 3   T2R13B4      dulled           3  /content/Impala/dataset/tool/T2R13B4.jpg
# 1    T1R7B4        used           2   /content/Impala/dataset/tool/T1R7B4.jpg
#
#                                         spec_x  \
# 14   /content/Impala/dataset/spec/x/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/x/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/x/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/x/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/x/T1R7B4.jpg
#
#                                         spec_y  \
# 14   /content/Impala/dataset/spec/y/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/y/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/y/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/y/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/y/T1R7B4.jpg
#
#                                         spec_z  \
# 14   /content/Impala/dataset/spec/z/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/z/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/z/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/z/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/z/T1R7B4.jpg
#
#                                         chip  \
# 14   /content/Impala/dataset/chip/T8R3B4.jpg
# 10   /content/Impala/dataset/chip/T6R9B3.jpg
# 0    /content/Impala/dataset/chip/T1R2B1.jpg
# 3   /content/Impala/dataset/chip/T2R13B4.jpg
# 1    /content/Impala/dataset/chip/T1R7B4.jpg
#
#                                         work
# 14   /content/Impala/dataset/work/T8R3B4.png
# 10   /content/Impala/dataset/work/T6R9B3.png
# 0    /content/Impala/dataset/work/T1R2B1.png
# 3   /content/Impala/dataset/work/T2R13B4.png
# 1    /content/Impala/dataset/work/T1R7B4.png
# test_head          id image_label  tool_label                                      tool  \
# 16   T9R7B4        used           2   /content/Impala/dataset/tool/T9R7B4.jpg
# 18  T10R3B4       sharp           1  /content/Impala/dataset/tool/T10R3B4.jpg
# 9   T5R12B1      dulled           3  /content/Impala/dataset/tool/T5R12B1.jpg
#
#                                         spec_x  \
# 16   /content/Impala/dataset/spec/x/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/x/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/x/T5R12B1.jpg
#
#                                         spec_y  \
# 16   /content/Impala/dataset/spec/y/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/y/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/y/T5R12B1.jpg
#
#                                         spec_z  \
# 16   /content/Impala/dataset/spec/z/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/z/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/z/T5R12B1.jpg
#
#                                         chip  \
# 16   /content/Impala/dataset/chip/T9R7B4.jpg
# 18  /content/Impala/dataset/chip/T10R3B4.jpg
# 9   /content/Impala/dataset/chip/T5R12B1.jpg
#
#                                         work
# 16   /content/Impala/dataset/work/T9R7B4.png
# 18  /content/Impala/dataset/work/T10R3B4.png
# 9   /content/Impala/dataset/work/T5R12B1.png
# val_head          id image_label  tool_label                                      tool  \
# 5   T3R10B1      dulled           3  /content/Impala/dataset/tool/T3R10B1.jpg
# 13  T7R14B3      dulled           3  /content/Impala/dataset/tool/T7R14B3.jpg
# 12   T7R8B3        used           2   /content/Impala/dataset/tool/T7R8B3.jpg
#
#                                         spec_x  \
# 5   /content/Impala/dataset/spec/x/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/x/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/x/T7R8B3.jpg
#
#                                         spec_y  \
# 5   /content/Impala/dataset/spec/y/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/y/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/y/T7R8B3.jpg
#
#                                         spec_z  \
# 5   /content/Impala/dataset/spec/z/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/z/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/z/T7R8B3.jpg
#
#                                         chip  \
# 5   /content/Impala/dataset/chip/T3R10B1.jpg
# 13  /content/Impala/dataset/chip/T7R14B3.jpg
# 12   /content/Impala/dataset/chip/T7R8B3.jpg
#
#                                         work
# 5   /content/Impala/dataset/work/T3R10B1.png
# 13  /content/Impala/dataset/work/T7R14B3.png
# 12   /content/Impala/dataset/work/T7R8B3.png

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images


def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []
    for i in range(file_paths_x.size):
        img = []
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_x)

        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_y)

        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_z)
        img = np.concatenate(img, axis=2)
        images.append(img)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    return images

# %%
x_train_tool = read_tools(train_df.tool.values, img_rows, img_cols, in_channel_tool)
x_test_tool = read_tools(test_df.tool.values, img_rows, img_cols, in_channel_tool)
x_val_tool = read_tools(val_df.tool.values, img_rows, img_cols, in_channel_tool)

x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel_spec,
)

x_train_chip = read_tools(train_df.chip.values, img_rows, img_cols, in_channel_chip)
x_test_chip = read_tools(test_df.chip.values, img_rows, img_cols, in_channel_chip)
x_val_chip = read_tools(val_df.chip.values, img_rows, img_cols, in_channel_chip)

x_train_work = read_tools(train_df.work.values, img_rows, img_cols, in_channel_work)
x_test_work = read_tools(test_df.work.values, img_rows, img_cols, in_channel_work)
x_val_work = read_tools(val_df.work.values, img_rows, img_cols, in_channel_work)

# %%
x_train_tool.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
x_train_chip.shape
# Out:
# (14, 256, 256, 3)

# %%
x_train_work.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img_tool = tf.keras.utils.array_to_img(x_train_tool[0])
pil_img_spec_x = tf.keras.utils.array_to_img(x_train_spec[0][:,:,:3])
pil_img_spec_y = tf.keras.utils.array_to_img(x_train_spec[0][:,:,3:6])
pil_img_spec_z = tf.keras.utils.array_to_img(x_train_spec[0][:,:,6:9])
pil_img_chip = tf.keras.utils.array_to_img(x_train_chip[0])
pil_img_work = tf.keras.utils.array_to_img(x_train_work[0])
fig, ax = plt.subplots(2, 3, figsize=(12, 8))
ax[0][0].imshow(pil_img_tool)
ax[0][1].imshow(pil_img_chip)
ax[0][2].imshow(pil_img_work)
ax[1][0].imshow(pil_img_spec_x)
ax[1][1].imshow(pil_img_spec_y)
ax[1][2].imshow(pil_img_spec_z)
ax[0][0].set_title("tool")
ax[0][1].set_title("chip")
ax[0][2].set_title("work")
ax[1][0].set_title("spec_x")
ax[1][1].set_title("spec_y")
ax[1][2].set_title("spec_z")
plt.show()

# %%
labels_train = train_df.tool_label.values
labels_test = test_df.tool_label.values
labels_val = val_df.tool_label.values

labels_train
# Out:
# array([1, 2, 1, 3, 2, 2, 3, 2, 1, 1, 3, 1, 2, 3])

# %%
labels_train = labels_train - 1
labels_test = labels_test - 1
labels_val = labels_val - 1

labels_train = tf.keras.utils.to_categorical(
    labels_train, num_classes=num_classes, dtype="float32"
)
labels_test = tf.keras.utils.to_categorical(
    labels_test, num_classes=num_classes, dtype="float32"
)
labels_val = tf.keras.utils.to_categorical(
    labels_val, num_classes=num_classes, dtype="float32"
)

# %%
# ============================== augment 1/4 ==============================
data_augmentation_tool = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_tool",
)

# %%
# ============================== augment 2/4 ==============================
data_augmentation_spec = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_spec",
)

# %%
# ============================== augment 3/4 ==============================
data_augmentation_chip = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_chip",
)

# %%
# ============================== augment 4/4 ==============================
data_augmentation_work = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation_work",
)

# %%
x_train_tool = data_augmentation_tool(x_train_tool)
x_train_spec = data_augmentation_spec(x_train_spec)
x_train_chip = data_augmentation_chip(x_train_chip)
x_train_work = data_augmentation_work(x_train_work)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_train_tool,
            "input_1_spec": x_train_spec,
            "input_1_chip": x_train_chip,
            "input_1_work": x_train_work,
        },
        labels_train,
    )
)
test_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_test_tool,
            "input_1_spec": x_test_spec,
            "input_1_chip": x_test_chip,
            "input_1_work": x_test_work,
        },
        labels_test,
    )
)
val_dataset = tf.data.Dataset.from_tensor_slices(
    (
        {
            "input_1_tool": x_val_tool,
            "input_1_spec": x_val_spec,
            "input_1_chip": x_val_chip,
            "input_1_work": x_val_work,
        },
        labels_val,
    )
)

# %%
auto = tf.data.AUTOTUNE
inputs1 = k.Input(input_shape_tool)
inputs2 = k.Input(input_shape_spec)
inputs4 = k.Input(input_shape_chip)
inputs5 = k.Input(input_shape_work)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        pass
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=({'input_1_tool': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_spec': TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), 'input_1_chip': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), 'input_1_work': TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.float32, name=None))>

# %%
# ============================== build/load model(s) ==============================
model_tool = k.models.load_model(model_tool_path, compile=False)
model_spec = k.models.load_model(model_spec_path, compile=False)
model_chip = k.models.load_model(model_chip_path, compile=False)
model_work = k.models.load_model(model_work_path, compile=False)

model_tool.trainable = False
model_spec.trainable = False
model_chip.trainable = False
model_work.trainable = False


def multimodal_conv_build(model_tool, model_spec, model_chip, model_work):
    inputs1 = model_tool.input
    inputs1._name = "input_tool"
    inputs2 = model_spec.input
    inputs2._name = "input_spec"
    inputs3 = model_chip.input
    inputs3._name = "input_chip"
    inputs4 = model_work.input
    inputs4._name = "input_work"

    truncated_model_tool = k.Model(
        inputs=model_tool.input, outputs=model_tool.layers[-2].output
    )
    truncated_model_spec = k.Model(
        inputs=model_spec.input, outputs=model_spec.layers[-2].output
    )
    truncated_model_chip = k.Model(
        inputs=model_chip.input, outputs=model_chip.layers[-2].output
    )
    truncated_model_work = k.Model(
        inputs=model_work.input, outputs=model_work.layers[-2].output
    )
    mergedOut = k.layers.Concatenate()(
        [
            truncated_model_tool.output,
            truncated_model_spec.output,
            truncated_model_chip.output,
            truncated_model_work.output,
        ]
    )
    output = layers.Dense(num_classes, activation="softmax", name="output_mult")(
        mergedOut
    )
    return k.Model(inputs=[inputs1, inputs2, inputs3, inputs4], outputs=output)


for layer in model_tool.layers:
    layer._name = layer.name + str("_tool")
for layer in model_spec.layers:
    layer._name = layer.name + str("_spec")
for layer in model_chip.layers:
    layer._name = layer.name + str("_chip")
for layer in model_work.layers:
    layer._name = layer.name + str("_work")

# %%
# ============================== run experiment ==============================
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, model

# %%
model = multimodal_conv_build(model_tool, model_spec, model_chip, model_work)
model.summary()
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#  batch_normalization_44_chi  (None, 16, 16, 256)          1024      ['activation_44_chip[0][0]']
#  p (BatchNormalization)
#
#  conv2d_20_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_43_work[0][0]']
#
#  batch_normalization_44_wor  (None, 16, 16, 256)          1024      ['activation_44_work[0][0]']
#  k (BatchNormalization)
#
#  activation_40_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_20_tool[0][0]']
#  tion)
#
#  add_52_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_36_tool[
#                                                                     0][0]',
#                                                                      'batch_normalization_44_tool[
#                                                                     0][0]']
#
#  activation_40_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_20_spec[0][0]']
#  tion)
#
#  add_52_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_36_spec[
#                                                                     0][0]',
#                                                                      'batch_normalization_44_spec[
#                                                                     0][0]']
#
#  activation_40_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_20_chip[0][0]']
#  tion)
#
#  add_52_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_36_chip[
#                                                                     0][0]',
#                                                                      'batch_normalization_44_chip[
#                                                                     0][0]']
#
#  activation_40_work (Activa  (None, 16, 16, 256)          0         ['conv2d_20_work[0][0]']
#  tion)
#
#  add_52_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_36_work[
#                                                                     0][0]',
#                                                                      'batch_normalization_44_work[
#                                                                     0][0]']
#
#  batch_normalization_40_too  (None, 16, 16, 256)          1024      ['activation_40_tool[0][0]']
#  l (BatchNormalization)
#
#  add_53_tool (Add)           (None, 16, 16, 256)          0         ['add_9_tool[0][0]',
#                                                                      'add_52_tool[0][0]']
#
#  batch_normalization_40_spe  (None, 16, 16, 256)          1024      ['activation_40_spec[0][0]']
#  c (BatchNormalization)
#
#  add_53_spec (Add)           (None, 16, 16, 256)          0         ['add_9_spec[0][0]',
#                                                                      'add_52_spec[0][0]']
#
#  batch_normalization_40_chi  (None, 16, 16, 256)          1024      ['activation_40_chip[0][0]']
#  p (BatchNormalization)
#
#  add_53_chip (Add)           (None, 16, 16, 256)          0         ['add_9_chip[0][0]',
#                                                                      'add_52_chip[0][0]']
#
#  batch_normalization_40_wor  (None, 16, 16, 256)          1024      ['activation_40_work[0][0]']
#  k (BatchNormalization)
#
#  add_53_work (Add)           (None, 16, 16, 256)          0         ['add_9_work[0][0]',
#                                                                      'add_52_work[0][0]']
#
#  add_54_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_40_tool[
#                                                                     0][0]',
#                                                                      'add_53_tool[0][0]']
#
#  add_62_tool (Add)           (None, 16, 16, 256)          0         ['add_53_tool[0][0]',
#                                                                      'batch_normalization_tool[0][
#                                                                     0]']
#
#  add_54_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_40_spec[
#                                                                     0][0]',
#                                                                      'add_53_spec[0][0]']
#
#  add_62_spec (Add)           (None, 16, 16, 256)          0         ['add_53_spec[0][0]',
#                                                                      'batch_normalization_spec[0][
#                                                                     0]']
#
#  add_54_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_40_chip[
#                                                                     0][0]',
#                                                                      'add_53_chip[0][0]']
#
#  add_62_chip (Add)           (None, 16, 16, 256)          0         ['add_53_chip[0][0]',
#                                                                      'batch_normalization_chip[0][
#                                                                     0]']
#
#  add_54_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_40_work[
#                                                                     0][0]',
#                                                                      'add_53_work[0][0]']
#
#  add_62_work (Add)           (None, 16, 16, 256)          0         ['add_53_work[0][0]',
#                                                                      'batch_normalization_work[0][
#                                                                     0]']
#
#  depthwise_conv2d_22_tool (  (None, 16, 16, 256)          6656      ['add_54_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_24_tool (  (None, 16, 16, 256)          6656      ['add_62_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_22_spec (  (None, 16, 16, 256)          6656      ['add_54_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_24_spec (  (None, 16, 16, 256)          6656      ['add_62_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_22_chip (  (None, 16, 16, 256)          6656      ['add_54_chip[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_24_chip (  (None, 16, 16, 256)          6656      ['add_62_chip[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_22_work (  (None, 16, 16, 256)          6656      ['add_54_work[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_24_work (  (None, 16, 16, 256)          6656      ['add_62_work[0][0]']
#  DepthwiseConv2D)
#
#  activation_45_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_22_tool[0][
#  tion)                                                              0]']
#
#  activation_49_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_24_tool[0][
#  tion)                                                              0]']
#
#  activation_45_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_22_spec[0][
#  tion)                                                              0]']
#
#  activation_49_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_24_spec[0][
#  tion)                                                              0]']
#
#  activation_45_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_22_chip[0][
#  tion)                                                              0]']
#
#  activation_49_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_24_chip[0][
#  tion)                                                              0]']
#
#  activation_45_work (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_22_work[0][
#  tion)                                                              0]']
#
#  activation_49_work (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_24_work[0][
#  tion)                                                              0]']
#
#  batch_normalization_45_too  (None, 16, 16, 256)          1024      ['activation_45_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_49_too  (None, 16, 16, 256)          1024      ['activation_49_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_45_spe  (None, 16, 16, 256)          1024      ['activation_45_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_49_spe  (None, 16, 16, 256)          1024      ['activation_49_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_45_chi  (None, 16, 16, 256)          1024      ['activation_45_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_49_chi  (None, 16, 16, 256)          1024      ['activation_49_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_45_wor  (None, 16, 16, 256)          1024      ['activation_45_work[0][0]']
#  k (BatchNormalization)
#
#  batch_normalization_49_wor  (None, 16, 16, 256)          1024      ['activation_49_work[0][0]']
#  k (BatchNormalization)
#
#  add_56_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_45_tool[
#                                                                     0][0]',
#                                                                      'add_54_tool[0][0]']
#
#  add_63_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_49_tool[
#                                                                     0][0]',
#                                                                      'add_62_tool[0][0]']
#
#  add_56_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_45_spec[
#                                                                     0][0]',
#                                                                      'add_54_spec[0][0]']
#
#  add_63_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_49_spec[
#                                                                     0][0]',
#                                                                      'add_62_spec[0][0]']
#
#  add_56_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_45_chip[
#                                                                     0][0]',
#                                                                      'add_54_chip[0][0]']
#
#  add_63_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_49_chip[
#                                                                     0][0]',
#                                                                      'add_62_chip[0][0]']
#
#  add_56_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_45_work[
#                                                                     0][0]',
#                                                                      'add_54_work[0][0]']
#
#  add_63_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_49_work[
#                                                                     0][0]',
#                                                                      'add_62_work[0][0]']
#
#  conv2d_23_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_56_tool[0][0]']
#
#  conv2d_25_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_63_tool[0][0]']
#
#  conv2d_23_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_56_spec[0][0]']
#
#  conv2d_25_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_63_spec[0][0]']
#
#  conv2d_23_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_56_chip[0][0]']
#
#  conv2d_25_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_63_chip[0][0]']
#
#  conv2d_23_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_56_work[0][0]']
#
#  conv2d_25_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_63_work[0][0]']
#
#  activation_46_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_23_tool[0][0]']
#  tion)
#
#  activation_50_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_25_tool[0][0]']
#  tion)
#
#  activation_46_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_23_spec[0][0]']
#  tion)
#
#  activation_50_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_25_spec[0][0]']
#  tion)
#
#  activation_46_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_23_chip[0][0]']
#  tion)
#
#  activation_50_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_25_chip[0][0]']
#  tion)
#
#  activation_46_work (Activa  (None, 16, 16, 256)          0         ['conv2d_23_work[0][0]']
#  tion)
#
#  activation_50_work (Activa  (None, 16, 16, 256)          0         ['conv2d_25_work[0][0]']
#  tion)
#
#  batch_normalization_46_too  (None, 16, 16, 256)          1024      ['activation_46_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_50_too  (None, 16, 16, 256)          1024      ['activation_50_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_46_spe  (None, 16, 16, 256)          1024      ['activation_46_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_50_spe  (None, 16, 16, 256)          1024      ['activation_50_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_46_chi  (None, 16, 16, 256)          1024      ['activation_46_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_50_chi  (None, 16, 16, 256)          1024      ['activation_50_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_46_wor  (None, 16, 16, 256)          1024      ['activation_46_work[0][0]']
#  k (BatchNormalization)
#
#  batch_normalization_50_wor  (None, 16, 16, 256)          1024      ['activation_50_work[0][0]']
#  k (BatchNormalization)
#
#  add_57_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_38_tool[
#                                                                     0][0]',
#                                                                      'batch_normalization_46_tool[
#                                                                     0][0]']
#
#  add_64_tool (Add)           (None, 16, 16, 256)          0         ['add_48_tool[0][0]',
#                                                                      'batch_normalization_50_tool[
#                                                                     0][0]']
#
#  add_57_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_38_spec[
#                                                                     0][0]',
#                                                                      'batch_normalization_46_spec[
#                                                                     0][0]']
#
#  add_64_spec (Add)           (None, 16, 16, 256)          0         ['add_48_spec[0][0]',
#                                                                      'batch_normalization_50_spec[
#                                                                     0][0]']
#
#  add_57_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_38_chip[
#                                                                     0][0]',
#                                                                      'batch_normalization_46_chip[
#                                                                     0][0]']
#
#  add_64_chip (Add)           (None, 16, 16, 256)          0         ['add_48_chip[0][0]',
#                                                                      'batch_normalization_50_chip[
#                                                                     0][0]']
#
#  add_57_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_38_work[
#                                                                     0][0]',
#                                                                      'batch_normalization_46_work[
#                                                                     0][0]']
#
#  add_64_work (Add)           (None, 16, 16, 256)          0         ['add_48_work[0][0]',
#                                                                      'batch_normalization_50_work[
#                                                                     0][0]']
#
#  add_58_tool (Add)           (None, 16, 16, 256)          0         ['add_12_tool[0][0]',
#                                                                      'add_57_tool[0][0]']
#
#  add_65_tool (Add)           (None, 16, 16, 256)          0         ['add_17_tool[0][0]',
#                                                                      'add_64_tool[0][0]']
#
#  add_58_spec (Add)           (None, 16, 16, 256)          0         ['add_12_spec[0][0]',
#                                                                      'add_57_spec[0][0]']
#
#  add_65_spec (Add)           (None, 16, 16, 256)          0         ['add_17_spec[0][0]',
#                                                                      'add_64_spec[0][0]']
#
#  add_58_chip (Add)           (None, 16, 16, 256)          0         ['add_12_chip[0][0]',
#                                                                      'add_57_chip[0][0]']
#
#  add_65_chip (Add)           (None, 16, 16, 256)          0         ['add_17_chip[0][0]',
#                                                                      'add_64_chip[0][0]']
#
#  add_58_work (Add)           (None, 16, 16, 256)          0         ['add_12_work[0][0]',
#                                                                      'add_57_work[0][0]']
#
#  add_65_work (Add)           (None, 16, 16, 256)          0         ['add_17_work[0][0]',
#                                                                      'add_64_work[0][0]']
#
#  add_66_tool (Add)           (None, 16, 16, 256)          0         ['add_58_tool[0][0]',
#                                                                      'add_65_tool[0][0]']
#
#  add_66_spec (Add)           (None, 16, 16, 256)          0         ['add_58_spec[0][0]',
#                                                                      'add_65_spec[0][0]']
#
#  add_66_chip (Add)           (None, 16, 16, 256)          0         ['add_58_chip[0][0]',
#                                                                      'add_65_chip[0][0]']
#
#  add_66_work (Add)           (None, 16, 16, 256)          0         ['add_58_work[0][0]',
#                                                                      'add_65_work[0][0]']
#
#  depthwise_conv2d_23_tool (  (None, 16, 16, 256)          6656      ['add_58_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_25_tool (  (None, 16, 16, 256)          6656      ['add_66_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_23_spec (  (None, 16, 16, 256)          6656      ['add_58_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_25_spec (  (None, 16, 16, 256)          6656      ['add_66_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_23_chip (  (None, 16, 16, 256)          6656      ['add_58_chip[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_25_chip (  (None, 16, 16, 256)          6656      ['add_66_chip[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_23_work (  (None, 16, 16, 256)          6656      ['add_58_work[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_25_work (  (None, 16, 16, 256)          6656      ['add_66_work[0][0]']
#  DepthwiseConv2D)
#
#  activation_47_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_23_tool[0][
#  tion)                                                              0]']
#
#  activation_51_tool (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_25_tool[0][
#  tion)                                                              0]']
#
#  activation_47_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_23_spec[0][
#  tion)                                                              0]']
#
#  activation_51_spec (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_25_spec[0][
#  tion)                                                              0]']
#
#  activation_47_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_23_chip[0][
#  tion)                                                              0]']
#
#  activation_51_chip (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_25_chip[0][
#  tion)                                                              0]']
#
#  activation_47_work (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_23_work[0][
#  tion)                                                              0]']
#
#  activation_51_work (Activa  (None, 16, 16, 256)          0         ['depthwise_conv2d_25_work[0][
#  tion)                                                              0]']
#
#  batch_normalization_47_too  (None, 16, 16, 256)          1024      ['activation_47_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_51_too  (None, 16, 16, 256)          1024      ['activation_51_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_47_spe  (None, 16, 16, 256)          1024      ['activation_47_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_51_spe  (None, 16, 16, 256)          1024      ['activation_51_spec[0][0]']
#  c (BatchNormalization)
#
#  batch_normalization_47_chi  (None, 16, 16, 256)          1024      ['activation_47_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_51_chi  (None, 16, 16, 256)          1024      ['activation_51_chip[0][0]']
#  p (BatchNormalization)
#
#  batch_normalization_47_wor  (None, 16, 16, 256)          1024      ['activation_47_work[0][0]']
#  k (BatchNormalization)
#
#  batch_normalization_51_wor  (None, 16, 16, 256)          1024      ['activation_51_work[0][0]']
#  k (BatchNormalization)
#
#  add_59_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_47_tool[
#                                                                     0][0]',
#                                                                      'add_58_tool[0][0]']
#
#  add_68_tool (Add)           (None, 16, 16, 256)          0         ['batch_normalization_51_tool[
#                                                                     0][0]',
#                                                                      'add_66_tool[0][0]']
#
#  add_59_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_47_spec[
#                                                                     0][0]',
#                                                                      'add_58_spec[0][0]']
#
#  add_68_spec (Add)           (None, 16, 16, 256)          0         ['batch_normalization_51_spec[
#                                                                     0][0]',
#                                                                      'add_66_spec[0][0]']
#
#  add_59_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_47_chip[
#                                                                     0][0]',
#                                                                      'add_58_chip[0][0]']
#
#  add_68_chip (Add)           (None, 16, 16, 256)          0         ['batch_normalization_51_chip[
#                                                                     0][0]',
#                                                                      'add_66_chip[0][0]']
#
#  add_59_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_47_work[
#                                                                     0][0]',
#                                                                      'add_58_work[0][0]']
#
#  add_68_work (Add)           (None, 16, 16, 256)          0         ['batch_normalization_51_work[
#                                                                     0][0]',
#                                                                      'add_66_work[0][0]']
#
#  conv2d_24_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_59_tool[0][0]']
#
#  conv2d_26_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_68_tool[0][0]']
#
#  conv2d_24_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_59_spec[0][0]']
#
#  conv2d_26_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_68_spec[0][0]']
#
#  conv2d_24_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_59_chip[0][0]']
#
#  conv2d_26_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_68_chip[0][0]']
#
#  conv2d_24_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_59_work[0][0]']
#
#  conv2d_26_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_68_work[0][0]']
#
#  activation_48_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_24_tool[0][0]']
#  tion)
#
#  activation_52_tool (Activa  (None, 16, 16, 256)          0         ['conv2d_26_tool[0][0]']
#  tion)
#
#  activation_48_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_24_spec[0][0]']
#  tion)
#
#  activation_52_spec (Activa  (None, 16, 16, 256)          0         ['conv2d_26_spec[0][0]']
#  tion)
#
#  activation_48_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_24_chip[0][0]']
#  tion)
#
#  activation_52_chip (Activa  (None, 16, 16, 256)          0         ['conv2d_26_chip[0][0]']
#  tion)
#
#  activation_48_work (Activa  (None, 16, 16, 256)          0         ['conv2d_24_work[0][0]']
#  tion)
#
#  activation_52_work (Activa  (None, 16, 16, 256)          0         ['conv2d_26_work[0][0]']
#  tion)
#
#  batch_normalization_48_too  (None, 16, 16, 256)          1024      ['activation_48_tool[0][0]']
#  l (BatchNormalization)
#
#  batch_normalization_52_too  (None, 16, 16, 256)          1024      ['activation_52_tool[0][0]']
# ...
#                                                                      'batch_normalization_126_chip
#                                                                     [0][0]']
#
#  add_209_work (Add)          (None, 16, 16, 256)          0         ['add_193_work[0][0]',
#                                                                      'batch_normalization_126_work
#                                                                     [0][0]']
#
#  add_210_tool (Add)          (None, 16, 16, 256)          0         ['add_151_tool[0][0]',
#                                                                      'add_209_tool[0][0]']
#
#  add_210_spec (Add)          (None, 16, 16, 256)          0         ['add_151_spec[0][0]',
#                                                                      'add_209_spec[0][0]']
#
#  add_210_chip (Add)          (None, 16, 16, 256)          0         ['add_151_chip[0][0]',
#                                                                      'add_209_chip[0][0]']
#
#  add_210_work (Add)          (None, 16, 16, 256)          0         ['add_151_work[0][0]',
#                                                                      'add_209_work[0][0]']
#
#  depthwise_conv2d_63_tool (  (None, 16, 16, 256)          6656      ['add_210_tool[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_63_spec (  (None, 16, 16, 256)          6656      ['add_210_spec[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_63_chip (  (None, 16, 16, 256)          6656      ['add_210_chip[0][0]']
#  DepthwiseConv2D)
#
#  depthwise_conv2d_63_work (  (None, 16, 16, 256)          6656      ['add_210_work[0][0]']
#  DepthwiseConv2D)
#
#  activation_127_tool (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_tool[0][
#  ation)                                                             0]']
#
#  activation_127_spec (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_spec[0][
#  ation)                                                             0]']
#
#  activation_127_chip (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_chip[0][
#  ation)                                                             0]']
#
#  activation_127_work (Activ  (None, 16, 16, 256)          0         ['depthwise_conv2d_63_work[0][
#  ation)                                                             0]']
#
#  batch_normalization_127_to  (None, 16, 16, 256)          1024      ['activation_127_tool[0][0]']
#  ol (BatchNormalization)
#
#  batch_normalization_127_sp  (None, 16, 16, 256)          1024      ['activation_127_spec[0][0]']
#  ec (BatchNormalization)
#
#  batch_normalization_127_ch  (None, 16, 16, 256)          1024      ['activation_127_chip[0][0]']
#  ip (BatchNormalization)
#
#  batch_normalization_127_wo  (None, 16, 16, 256)          1024      ['activation_127_work[0][0]']
#  rk (BatchNormalization)
#
#  add_211_tool (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_tool
#                                                                     [0][0]',
#                                                                      'add_210_tool[0][0]']
#
#  add_211_spec (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_spec
#                                                                     [0][0]',
#                                                                      'add_210_spec[0][0]']
#
#  add_211_chip (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_chip
#                                                                     [0][0]',
#                                                                      'add_210_chip[0][0]']
#
#  add_211_work (Add)          (None, 16, 16, 256)          0         ['batch_normalization_127_work
#                                                                     [0][0]',
#                                                                      'add_210_work[0][0]']
#
#  conv2d_64_tool (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_tool[0][0]']
#
#  conv2d_64_spec (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_spec[0][0]']
#
#  conv2d_64_chip (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_chip[0][0]']
#
#  conv2d_64_work (Conv2D)     (None, 16, 16, 256)          65792     ['add_211_work[0][0]']
#
#  activation_128_tool (Activ  (None, 16, 16, 256)          0         ['conv2d_64_tool[0][0]']
#  ation)
#
#  activation_128_spec (Activ  (None, 16, 16, 256)          0         ['conv2d_64_spec[0][0]']
#  ation)
#
#  activation_128_chip (Activ  (None, 16, 16, 256)          0         ['conv2d_64_chip[0][0]']
#  ation)
#
#  activation_128_work (Activ  (None, 16, 16, 256)          0         ['conv2d_64_work[0][0]']
#  ation)
#
#  batch_normalization_128_to  (None, 16, 16, 256)          1024      ['activation_128_tool[0][0]']
#  ol (BatchNormalization)
#
#  batch_normalization_128_sp  (None, 16, 16, 256)          1024      ['activation_128_spec[0][0]']
#  ec (BatchNormalization)
#
#  batch_normalization_128_ch  (None, 16, 16, 256)          1024      ['activation_128_chip[0][0]']
#  ip (BatchNormalization)
#
#  batch_normalization_128_wo  (None, 16, 16, 256)          1024      ['activation_128_work[0][0]']
#  rk (BatchNormalization)
#
#  add_212_tool (Add)          (None, 16, 16, 256)          0         ['add_196_tool[0][0]',
#                                                                      'batch_normalization_128_tool
#                                                                     [0][0]']
#
#  add_212_spec (Add)          (None, 16, 16, 256)          0         ['add_196_spec[0][0]',
#                                                                      'batch_normalization_128_spec
#                                                                     [0][0]']
#
#  add_212_chip (Add)          (None, 16, 16, 256)          0         ['add_196_chip[0][0]',
#                                                                      'batch_normalization_128_chip
#                                                                     [0][0]']
#
#  add_212_work (Add)          (None, 16, 16, 256)          0         ['add_196_work[0][0]',
#                                                                      'batch_normalization_128_work
#                                                                     [0][0]']
#
#  add_213_tool (Add)          (None, 16, 16, 256)          0         ['add_154_tool[0][0]',
#                                                                      'add_212_tool[0][0]']
#
#  add_213_spec (Add)          (None, 16, 16, 256)          0         ['add_154_spec[0][0]',
#                                                                      'add_212_spec[0][0]']
#
#  add_213_chip (Add)          (None, 16, 16, 256)          0         ['add_154_chip[0][0]',
#                                                                      'add_212_chip[0][0]']
#
#  add_213_work (Add)          (None, 16, 16, 256)          0         ['add_154_work[0][0]',
#                                                                      'add_212_work[0][0]']
#
#  global_average_pooling2d_t  (None, 256)                  0         ['add_213_tool[0][0]']
#  ool (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_s  (None, 256)                  0         ['add_213_spec[0][0]']
#  pec (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_c  (None, 256)                  0         ['add_213_chip[0][0]']
#  hip (GlobalAveragePooling2
#  D)
#
#  global_average_pooling2d_w  (None, 256)                  0         ['add_213_work[0][0]']
#  ork (GlobalAveragePooling2
#  D)
#
#  concatenate (Concatenate)   (None, 1024)                 0         ['global_average_pooling2d_too
#                                                                     l[0][0]',
#                                                                      'global_average_pooling2d_spe
#                                                                     c[0][0]',
#                                                                      'global_average_pooling2d_chi
#                                                                     p[0][0]',
#                                                                      'global_average_pooling2d_wor
#                                                                     k[0][0]']
#
#  output_mult (Dense)         (None, 3)                    3075      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 20258819 (77.28 MB)
# Trainable params: 3075 (12.01 KB)
# Non-trainable params: 20255744 (77.27 MB)
# __________________________________________________________________________________________________

# %%
history, model = run_experiment(model)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 87s 15s/step - loss: 1.4851 - accuracy: 0.5000 - val_loss: 0.7145 - val_accuracy: 0.6667
# Epoch 2/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.4008 - accuracy: 0.8571 - val_loss: 0.2870 - val_accuracy: 0.6667
# Epoch 3/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.1706 - accuracy: 0.9286 - val_loss: 0.1054 - val_accuracy: 1.0000
# Epoch 4/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.0732 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 1.0000
# Epoch 5/20
# 2/2 [==============================] - 5s 2s/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 1.0000
# Epoch 7/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 8/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 9/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 10/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 11/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 12/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 13/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 14/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 15/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 9.6608e-04 - val_accuracy: 1.0000
# Epoch 16/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 7.8210e-04 - val_accuracy: 1.0000
# Epoch 17/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 6.6073e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 5.7990e-04 - val_accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 5s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 5.2241e-04 - val_accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 5s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 4.8416e-04 - val_accuracy: 1.0000
# 1/1 [==============================] - 1s 786ms/step - loss: 0.0210 - accuracy: 1.0000
# Test accuracy: 100.0%

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 12s 12s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("model accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
x_test = test_ds
y_test = labels_test
y_score = model.predict(x_test)
y_test = y_test

n_classes = num_classes
# Plot linewidth.
lw = 2
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})" "".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})" "".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})" "".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic multi-class")
plt.legend(loc="lower right")
plt.show()
# Out:
# 1/1 [==============================] - 1s 774ms/step
# <ipython-input-37-0227eecc12f4>:27: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %%
y_classes = np.argmax(y_score, axis=1)
labels_test_f1 = np.argmax(y_test, axis=1)

print(metrics.confusion_matrix(labels_test_f1, y_classes))
print(classification_report(labels_test_f1, y_classes))
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         1
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
fpr, tpr, thresholds = metrics.roc_curve(labels_test_f1, y_classes, pos_label=2)
print("AUC: ", metrics.auc(fpr, tpr))
# Out:
# AUC:  1.0
