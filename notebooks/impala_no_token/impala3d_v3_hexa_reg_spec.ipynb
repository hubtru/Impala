# %%
# !pip install tensorflow_addons

# clone Impala repository, refresh folder to see the Imapala repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Impala
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# fatal: destination path 'Impala' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
# architecture
image_size = 256
filters = 256
depth = 4
columns = 4
widths = 4
kernel_size = 5
patch_size = 16
num_classes = 3

in_channel = 9
img_rows, img_cols = image_size, image_size
input_shape = (img_rows, img_cols, in_channel)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 20

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "spec"
exp_name = f"impala3d_v3_hexa_reg"
model_name = f"{exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

# dataset
csv_path = "/content/Impala/dataset/labels_reg_sample.csv"
spec_path = f"/content/Impala/dataset/{modality}"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chips/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["spec_x"] = train_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
test_df["spec_x"] = test_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")
val_df["spec_x"] = val_df.id.map(lambda id: f"{spec_path}/x/{id}.jpg")

train_df["spec_y"] = train_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
test_df["spec_y"] = test_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")
val_df["spec_y"] = val_df.id.map(lambda id: f"{spec_path}/y/{id}.jpg")

train_df["spec_z"] = train_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
test_df["spec_z"] = test_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
val_df["spec_z"] = val_df.id.map(lambda id: f"{spec_path}/z/{id}.jpg")
# Out:
# size check train/test/val 14 3 3 20

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))
sns.histplot(train_df["gaps"], ax=ax[0])
sns.histplot(train_df["flank_wear"], ax=ax[1])
sns.histplot(train_df["overhang"], ax=ax[2])
ax[0].set_title("Label Distribution")
ax[1].set_title("Label Distribution")
ax[2].set_title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                         spec_x  \
# 14   /content/Impala/dataset/spec/x/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/x/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/x/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/x/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/x/T1R7B4.jpg
#
#                                         spec_y  \
# 14   /content/Impala/dataset/spec/y/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/y/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/y/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/y/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/y/T1R7B4.jpg
#
#                                         spec_z
# 14   /content/Impala/dataset/spec/z/T8R3B4.jpg
# 10   /content/Impala/dataset/spec/z/T6R9B3.jpg
# 0    /content/Impala/dataset/spec/z/T1R2B1.jpg
# 3   /content/Impala/dataset/spec/z/T2R13B4.jpg
# 1    /content/Impala/dataset/spec/z/T1R7B4.jpg
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                         spec_x  \
# 16   /content/Impala/dataset/spec/x/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/x/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/x/T5R12B1.jpg
#
#                                         spec_y  \
# 16   /content/Impala/dataset/spec/y/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/y/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/y/T5R12B1.jpg
#
#                                         spec_z
# 16   /content/Impala/dataset/spec/z/T9R7B4.jpg
# 18  /content/Impala/dataset/spec/z/T10R3B4.jpg
# 9   /content/Impala/dataset/spec/z/T5R12B1.jpg
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                         spec_x  \
# 5   /content/Impala/dataset/spec/x/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/x/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/x/T7R8B3.jpg
#
#                                         spec_y  \
# 5   /content/Impala/dataset/spec/y/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/y/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/y/T7R8B3.jpg
#
#                                         spec_z
# 5   /content/Impala/dataset/spec/z/T3R10B1.jpg
# 13  /content/Impala/dataset/spec/z/T7R14B3.jpg
# 12   /content/Impala/dataset/spec/z/T7R8B3.jpg

# %%
def read_specs(file_paths_x, file_paths_y, file_paths_z, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []
    for i in range(file_paths_x.size):
        img = []
        img_x = cv2.imread(file_paths_x[i])
        res_x = cv2.resize(
            img_x, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_x)

        img_y = cv2.imread(file_paths_y[i])
        res_y = cv2.resize(
            img_y, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_y)

        img_z = cv2.imread(file_paths_z[i])
        res_z = cv2.resize(
            img_z, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC
        )
        img.append(res_z)
        img = np.concatenate(img, axis=2)
        images.append(img)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    return images

# %%
x_train_spec = read_specs(
    train_df.spec_x.values,
    train_df.spec_y.values,
    train_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel,
)
x_test_spec = read_specs(
    test_df.spec_x.values,
    test_df.spec_y.values,
    test_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel,
)
x_val_spec = read_specs(
    val_df.spec_x.values,
    val_df.spec_y.values,
    val_df.spec_z.values,
    img_rows,
    img_cols,
    in_channel,
)

# %%
x_train_spec.shape
# Out:
# (14, 256, 256, 9)

# %%
pil_img_x = tf.keras.utils.array_to_img(x_train_spec[0][:,:,:3])
pil_img_y = tf.keras.utils.array_to_img(x_train_spec[0][:,:,3:6])
pil_img_z = tf.keras.utils.array_to_img(x_train_spec[0][:,:,6:9])

fig, ax = plt.subplots(1,3, figsize=(12,4))
ax[0].imshow(pil_img_x)
ax[1].imshow(pil_img_y)
ax[2].imshow(pil_img_z)
ax[0].set_title("spec_x")
ax[1].set_title("spec_y")
ax[2].set_title("spec_z")
plt.show()

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_spec, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_spec, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_spec, labels_val))

# %%
# ============================== augment ==============================
auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation",
)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 9), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
# ============================== build model ==============================
def activation_block(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def conv_stem(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_block(x)


def conv_mixer_block(
    x, pe_block, column, level, depth, width, r_arr, filters: int, kernel_size: int
):
    if column == 0:
        # Depthwise convolution.
        x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
        x = layers.Add()([activation_block(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_block(x)

        if width != 0:
            x0 = fusion_block_double(r_arr[width - 1][column][level], x0)

        r_arr = reverasable_output_array(x, r_arr, width, column, level)
        return x, r_arr
    elif column != 0:
        if level == 0:
            x0 = fusion_block_double(r_arr[width][column - 1][level + 1], pe_block)
        elif level <= depth - 2:
            x0 = fusion_block_double(r_arr[width][column - 1][level + 1], x)
            if width != 0:
                x = fusion_block_double(r_arr[width - 1][column - 1][level + 1], x)
        else:
            x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x0)
        x = layers.Add()([activation_block(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_block(x)

        x = fusion_block_double(r_arr[width][column - 1][level], x)
        if width != 0:
            x = fusion_block_double(r_arr[width - 1][column][level], x)

        r_arr = reverasable_output_array(x, r_arr, width, column, level)

        return x, r_arr

    return x, r_arr


def fusion_block_double(x, y):
    return layers.Add()([x, y])


def reverasable_output_array(x, r_arr, width, column, level):
    r_arr[width][column][level] = x
    return r_arr


def get_conv_mixer_256_8(
    image_size=image_size,
    filters=filters,
    depth=depth,
    columns=columns,
    width=widths,
    kernel_size=kernel_size,
    patch_size=patch_size,
    num_classes=num_classes,
):
    r_arr = [
        [[None for _ in range(depth)] for _ in range(columns)] for _ in range(width)
    ]

    inputs = k.Input(input_shape)
    # x = layers.Rescaling(scale=1.0 / 255)(inputs)         # already rescaled

    # Extract patch embeddings.
    x = conv_stem(inputs, filters, patch_size)
    pe_block = x

    # ConvMixer blocks.
    for w in range(width):
        for column in range(columns):
            for level in range(depth):
                x, r_arr = conv_mixer_block(
                    x, pe_block, column, level, depth, w, r_arr, filters, kernel_size
                )

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="linear")(x)

    return k.Model(inputs, outputs)

# %%
# ============================== run experiment ==============================
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        verbose=2,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = get_conv_mixer_256_8()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 9)]        0         []
#
#  conv2d_65 (Conv2D)          (None, 16, 16, 256)          590080    ['input_2[0][0]']
#
#  activation_129 (Activation  (None, 16, 16, 256)          0         ['conv2d_65[0][0]']
#  )
#
#  batch_normalization_129 (B  (None, 16, 16, 256)          1024      ['activation_129[0][0]']
#  atchNormalization)
#
#  depthwise_conv2d_64 (Depth  (None, 16, 16, 256)          6656      ['batch_normalization_129[0][0
#  wiseConv2D)                                                        ]']
#
#  activation_130 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_64[0][0]']
#  )
#
#  batch_normalization_130 (B  (None, 16, 16, 256)          1024      ['activation_130[0][0]']
#  atchNormalization)
#
#  add_214 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_130[0][0
#                                                                     ]',
#                                                                      'batch_normalization_129[0][0
#                                                                     ]']
#
#  conv2d_66 (Conv2D)          (None, 16, 16, 256)          65792     ['add_214[0][0]']
#
#  activation_131 (Activation  (None, 16, 16, 256)          0         ['conv2d_66[0][0]']
#  )
#
#  batch_normalization_131 (B  (None, 16, 16, 256)          1024      ['activation_131[0][0]']
#  atchNormalization)
#
#  depthwise_conv2d_65 (Depth  (None, 16, 16, 256)          6656      ['batch_normalization_131[0][0
#  wiseConv2D)                                                        ]']
#
#  activation_132 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_65[0][0]']
#  )
#
#  batch_normalization_132 (B  (None, 16, 16, 256)          1024      ['activation_132[0][0]']
#  atchNormalization)
#
#  add_215 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_132[0][0
#                                                                     ]',
#                                                                      'batch_normalization_131[0][0
#                                                                     ]']
#
#  conv2d_67 (Conv2D)          (None, 16, 16, 256)          65792     ['add_215[0][0]']
#
#  activation_133 (Activation  (None, 16, 16, 256)          0         ['conv2d_67[0][0]']
#  )
#
#  batch_normalization_133 (B  (None, 16, 16, 256)          1024      ['activation_133[0][0]']
#  atchNormalization)
#
#  add_218 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_133[0][0
#                                                                     ]',
#                                                                      'batch_normalization_129[0][0
#                                                                     ]']
#
#  depthwise_conv2d_68 (Depth  (None, 16, 16, 256)          6656      ['add_218[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_66 (Depth  (None, 16, 16, 256)          6656      ['batch_normalization_133[0][0
#  wiseConv2D)                                                        ]']
#
#  activation_138 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_68[0][0]']
#  )
#
#  activation_134 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_66[0][0]']
#  )
#
#  batch_normalization_138 (B  (None, 16, 16, 256)          1024      ['activation_138[0][0]']
#  atchNormalization)
#
#  batch_normalization_134 (B  (None, 16, 16, 256)          1024      ['activation_134[0][0]']
#  atchNormalization)
#
#  add_219 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_138[0][0
#                                                                     ]',
#                                                                      'add_218[0][0]']
#
#  add_216 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_134[0][0
#                                                                     ]',
#                                                                      'batch_normalization_133[0][0
#                                                                     ]']
#
#  conv2d_70 (Conv2D)          (None, 16, 16, 256)          65792     ['add_219[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 16, 16, 256)          65792     ['add_216[0][0]']
#
#  activation_139 (Activation  (None, 16, 16, 256)          0         ['conv2d_70[0][0]']
#  )
#
#  activation_135 (Activation  (None, 16, 16, 256)          0         ['conv2d_68[0][0]']
#  )
#
#  batch_normalization_139 (B  (None, 16, 16, 256)          1024      ['activation_139[0][0]']
#  atchNormalization)
#
#  batch_normalization_135 (B  (None, 16, 16, 256)          1024      ['activation_135[0][0]']
#  atchNormalization)
#
#  add_220 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_131[0][0
#                                                                     ]',
#                                                                      'batch_normalization_139[0][0
#                                                                     ]']
#
#  add_221 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_135[0][0
#                                                                     ]',
#                                                                      'add_220[0][0]']
#
#  depthwise_conv2d_69 (Depth  (None, 16, 16, 256)          6656      ['add_221[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_67 (Depth  (None, 16, 16, 256)          6656      ['batch_normalization_135[0][0
#  wiseConv2D)                                                        ]']
#
#  activation_140 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_69[0][0]']
#  )
#
#  activation_136 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_67[0][0]']
#  )
#
#  batch_normalization_140 (B  (None, 16, 16, 256)          1024      ['activation_140[0][0]']
#  atchNormalization)
#
#  batch_normalization_136 (B  (None, 16, 16, 256)          1024      ['activation_136[0][0]']
#  atchNormalization)
#
#  add_222 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_140[0][0
#                                                                     ]',
#                                                                      'add_221[0][0]']
#
#  add_217 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_136[0][0
#                                                                     ]',
#                                                                      'batch_normalization_135[0][0
#                                                                     ]']
#
#  conv2d_71 (Conv2D)          (None, 16, 16, 256)          65792     ['add_222[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 16, 16, 256)          65792     ['add_217[0][0]']
#
#  activation_141 (Activation  (None, 16, 16, 256)          0         ['conv2d_71[0][0]']
#  )
#
#  activation_137 (Activation  (None, 16, 16, 256)          0         ['conv2d_69[0][0]']
#  )
#
#  batch_normalization_141 (B  (None, 16, 16, 256)          1024      ['activation_141[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 16, 16, 256)          1024      ['activation_137[0][0]']
#  atchNormalization)
#
#  add_223 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_133[0][0
#                                                                     ]',
#                                                                      'batch_normalization_141[0][0
#                                                                     ]']
#
#  add_224 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_137[0][0
#                                                                     ]',
#                                                                      'add_223[0][0]']
#
#  add_229 (Add)               (None, 16, 16, 256)          0         ['add_223[0][0]',
#                                                                      'batch_normalization_129[0][0
#                                                                     ]']
#
#  depthwise_conv2d_70 (Depth  (None, 16, 16, 256)          6656      ['add_224[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_72 (Depth  (None, 16, 16, 256)          6656      ['add_229[0][0]']
#  wiseConv2D)
#
#  activation_142 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_70[0][0]']
#  )
#
#  activation_146 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_72[0][0]']
#  )
#
#  batch_normalization_142 (B  (None, 16, 16, 256)          1024      ['activation_142[0][0]']
#  atchNormalization)
#
#  batch_normalization_146 (B  (None, 16, 16, 256)          1024      ['activation_146[0][0]']
#  atchNormalization)
#
#  add_225 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_142[0][0
#                                                                     ]',
#                                                                      'add_224[0][0]']
#
#  add_230 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_146[0][0
#                                                                     ]',
#                                                                      'add_229[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 16, 16, 256)          65792     ['add_225[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 16, 16, 256)          65792     ['add_230[0][0]']
#
#  activation_143 (Activation  (None, 16, 16, 256)          0         ['conv2d_72[0][0]']
#  )
#
#  activation_147 (Activation  (None, 16, 16, 256)          0         ['conv2d_74[0][0]']
#  )
#
#  batch_normalization_143 (B  (None, 16, 16, 256)          1024      ['activation_143[0][0]']
#  atchNormalization)
#
#  batch_normalization_147 (B  (None, 16, 16, 256)          1024      ['activation_147[0][0]']
#  atchNormalization)
#
#  add_226 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_135[0][0
#                                                                     ]',
#                                                                      'batch_normalization_143[0][0
#                                                                     ]']
#
#  add_231 (Add)               (None, 16, 16, 256)          0         ['add_220[0][0]',
#                                                                      'batch_normalization_147[0][0
#                                                                     ]']
#
#  add_232 (Add)               (None, 16, 16, 256)          0         ['add_226[0][0]',
#                                                                      'add_231[0][0]']
#
#  depthwise_conv2d_71 (Depth  (None, 16, 16, 256)          6656      ['add_226[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_73 (Depth  (None, 16, 16, 256)          6656      ['add_232[0][0]']
#  wiseConv2D)
#
#  activation_144 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_71[0][0]']
#  )
#
#  activation_148 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_73[0][0]']
#  )
#
#  batch_normalization_144 (B  (None, 16, 16, 256)          1024      ['activation_144[0][0]']
#  atchNormalization)
#
#  batch_normalization_148 (B  (None, 16, 16, 256)          1024      ['activation_148[0][0]']
#  atchNormalization)
#
#  add_227 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_144[0][0
#                                                                     ]',
#                                                                      'add_226[0][0]']
#
#  add_233 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_148[0][0
#                                                                     ]',
#                                                                      'add_232[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 16, 16, 256)          65792     ['add_227[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 16, 16, 256)          65792     ['add_233[0][0]']
#
#  activation_145 (Activation  (None, 16, 16, 256)          0         ['conv2d_73[0][0]']
#  )
#
#  activation_149 (Activation  (None, 16, 16, 256)          0         ['conv2d_75[0][0]']
#  )
#
#  batch_normalization_145 (B  (None, 16, 16, 256)          1024      ['activation_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_149 (B  (None, 16, 16, 256)          1024      ['activation_149[0][0]']
#  atchNormalization)
#
#  add_228 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_137[0][0
#                                                                     ]',
#                                                                      'batch_normalization_145[0][0
#                                                                     ]']
#
#  add_234 (Add)               (None, 16, 16, 256)          0         ['add_223[0][0]',
#                                                                      'batch_normalization_149[0][0
#                                                                     ]']
#
#  add_235 (Add)               (None, 16, 16, 256)          0         ['add_228[0][0]',
#                                                                      'add_234[0][0]']
#
#  add_240 (Add)               (None, 16, 16, 256)          0         ['add_234[0][0]',
#                                                                      'batch_normalization_129[0][0
#                                                                     ]']
#
#  depthwise_conv2d_74 (Depth  (None, 16, 16, 256)          6656      ['add_235[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_76 (Depth  (None, 16, 16, 256)          6656      ['add_240[0][0]']
#  wiseConv2D)
#
#  activation_150 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_74[0][0]']
#  )
#
#  activation_154 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_76[0][0]']
#  )
#
#  batch_normalization_150 (B  (None, 16, 16, 256)          1024      ['activation_150[0][0]']
#  atchNormalization)
#
#  batch_normalization_154 (B  (None, 16, 16, 256)          1024      ['activation_154[0][0]']
#  atchNormalization)
#
#  add_236 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_150[0][0
#                                                                     ]',
#                                                                      'add_235[0][0]']
#
#  add_241 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_154[0][0
#                                                                     ]',
#                                                                      'add_240[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 16, 16, 256)          65792     ['add_236[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 16, 16, 256)          65792     ['add_241[0][0]']
#
#  activation_151 (Activation  (None, 16, 16, 256)          0         ['conv2d_76[0][0]']
#  )
#
#  activation_155 (Activation  (None, 16, 16, 256)          0         ['conv2d_78[0][0]']
#  )
#
#  batch_normalization_151 (B  (None, 16, 16, 256)          1024      ['activation_151[0][0]']
#  atchNormalization)
#
#  batch_normalization_155 (B  (None, 16, 16, 256)          1024      ['activation_155[0][0]']
#  atchNormalization)
#
#  add_237 (Add)               (None, 16, 16, 256)          0         ['add_226[0][0]',
#                                                                      'batch_normalization_151[0][0
#                                                                     ]']
#
#  add_242 (Add)               (None, 16, 16, 256)          0         ['add_231[0][0]',
#                                                                      'batch_normalization_155[0][0
#                                                                     ]']
#
#  add_243 (Add)               (None, 16, 16, 256)          0         ['add_237[0][0]',
#                                                                      'add_242[0][0]']
#
#  depthwise_conv2d_75 (Depth  (None, 16, 16, 256)          6656      ['add_237[0][0]']
#  wiseConv2D)
#
#  depthwise_conv2d_77 (Depth  (None, 16, 16, 256)          6656      ['add_243[0][0]']
#  wiseConv2D)
#
#  activation_152 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_75[0][0]']
#  )
#
#  activation_156 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_77[0][0]']
#  )
#
#  batch_normalization_152 (B  (None, 16, 16, 256)          1024      ['activation_152[0][0]']
#  atchNormalization)
#
#  batch_normalization_156 (B  (None, 16, 16, 256)          1024      ['activation_156[0][0]']
#  atchNormalization)
#
#  add_238 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_152[0][0
#                                                                     ]',
#                                                                      'add_237[0][0]']
#
#  add_244 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_156[0][0
#                                                                     ]',
#                                                                      'add_243[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 16, 16, 256)          65792     ['add_238[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 16, 16, 256)          65792     ['add_244[0][0]']
#
#  activation_153 (Activation  (None, 16, 16, 256)          0         ['conv2d_77[0][0]']
#  )
#
#  activation_157 (Activation  (None, 16, 16, 256)          0         ['conv2d_79[0][0]']
#  )
#
#  batch_normalization_153 (B  (None, 16, 16, 256)          1024      ['activation_153[0][0]']
#  atchNormalization)
#
#  batch_normalization_157 (B  (None, 16, 16, 256)          1024      ['activation_157[0][0]']
#  atchNormalization)
#
#  add_239 (Add)               (None, 16, 16, 256)          0         ['add_228[0][0]',
#                                                                      'batch_normalization_153[0][0
#                                                                     ]']
#
#  add_245 (Add)               (None, 16, 16, 256)          0         ['add_234[0][0]',
#                                                                      'batch_normalization_157[0][0
#                                                                     ]']
#
#  add_246 (Add)               (None, 16, 16, 256)          0         ['add_239[0][0]',
#                                                                      'add_245[0][0]']
#
#  depthwise_conv2d_78 (Depth  (None, 16, 16, 256)          6656      ['add_246[0][0]']
#  wiseConv2D)
#
#  activation_158 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_78[0][0]']
#  )
#
#  batch_normalization_158 (B  (None, 16, 16, 256)          1024      ['activation_158[0][0]']
#  atchNormalization)
#
#  add_247 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_158[0][0
#                                                                     ]',
#                                                                      'add_246[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 16, 16, 256)          65792     ['add_247[0][0]']
#
#  activation_159 (Activation  (None, 16, 16, 256)          0         ['conv2d_80[0][0]']
#  )
#
#  batch_normalization_159 (B  (None, 16, 16, 256)          1024      ['activation_159[0][0]']
#  atchNormalization)
#
#  add_248 (Add)               (None, 16, 16, 256)          0         ['add_237[0][0]',
#                                                                      'batch_normalization_159[0][0
#                                                                     ]']
#
#  depthwise_conv2d_79 (Depth  (None, 16, 16, 256)          6656      ['add_248[0][0]']
#  wiseConv2D)
#
#  activation_160 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_79[0][0]']
#  )
#
#  batch_normalization_160 (B  (None, 16, 16, 256)          1024      ['activation_160[0][0]']
#  atchNormalization)
#
#  add_249 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_160[0][0
#                                                                     ]',
#                                                                      'add_248[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 16, 16, 256)          65792     ['add_249[0][0]']
#
#  activation_161 (Activation  (None, 16, 16, 256)          0         ['conv2d_81[0][0]']
#  )
#
#  batch_normalization_161 (B  (None, 16, 16, 256)          1024      ['activation_161[0][0]']
#  atchNormalization)
#
#  add_250 (Add)               (None, 16, 16, 256)          0         ['add_239[0][0]',
#                                                                      'batch_normalization_161[0][0
#                                                                     ]']
#
#  depthwise_conv2d_80 (Depth  (None, 16, 16, 256)          6656      ['add_250[0][0]']
#  wiseConv2D)
#
#  activation_162 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_80[0][0]']
#  )
#
#  batch_normalization_162 (B  (None, 16, 16, 256)          1024      ['activation_162[0][0]']
#  atchNormalization)
#
#  add_251 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_162[0][0
#                                                                     ]',
#                                                                      'add_250[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 16, 16, 256)          65792     ['add_251[0][0]']
#
#  activation_163 (Activation  (None, 16, 16, 256)          0         ['conv2d_82[0][0]']
#  )
#
#  batch_normalization_163 (B  (None, 16, 16, 256)          1024      ['activation_163[0][0]']
#  atchNormalization)
#
#  depthwise_conv2d_81 (Depth  (None, 16, 16, 256)          6656      ['batch_normalization_163[0][0
#  wiseConv2D)                                                        ]']
#
#  activation_164 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_81[0][0]']
#  )
#
#  batch_normalization_164 (B  (None, 16, 16, 256)          1024      ['activation_164[0][0]']
#  atchNormalization)
#
#  add_253 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_164[0][0
#                                                                     ]',
#                                                                      'batch_normalization_163[0][0
#                                                                     ]']
#
#  conv2d_83 (Conv2D)          (None, 16, 16, 256)          65792     ['add_253[0][0]']
#
#  activation_165 (Activation  (None, 16, 16, 256)          0         ['conv2d_83[0][0]']
#  )
#
#  batch_normalization_165 (B  (None, 16, 16, 256)          1024      ['activation_165[0][0]']
#  atchNormalization)
#
#  add_259 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_165[0][0
#                                                                     ]',
#                                                                      'batch_normalization_129[0][0
# ...
#  add_412 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_250[0][0
#                                                                     ]',
#                                                                      'add_411[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 16, 16, 256)          65792     ['add_405[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 16, 16, 256)          65792     ['add_412[0][0]']
#
#  activation_247 (Activation  (None, 16, 16, 256)          0         ['conv2d_124[0][0]']
#  )
#
#  activation_251 (Activation  (None, 16, 16, 256)          0         ['conv2d_126[0][0]']
#  )
#
#  batch_normalization_247 (B  (None, 16, 16, 256)          1024      ['activation_247[0][0]']
#  atchNormalization)
#
#  batch_normalization_251 (B  (None, 16, 16, 256)          1024      ['activation_251[0][0]']
#  atchNormalization)
#
#  add_406 (Add)               (None, 16, 16, 256)          0         ['add_390[0][0]',
#                                                                      'batch_normalization_247[0][0
#                                                                     ]']
#
#  add_413 (Add)               (None, 16, 16, 256)          0         ['add_397[0][0]',
#                                                                      'batch_normalization_251[0][0
#                                                                     ]']
#
#  add_407 (Add)               (None, 16, 16, 256)          0         ['add_348[0][0]',
#                                                                      'add_406[0][0]']
#
#  add_414 (Add)               (None, 16, 16, 256)          0         ['add_355[0][0]',
#                                                                      'add_413[0][0]']
#
#  add_415 (Add)               (None, 16, 16, 256)          0         ['add_407[0][0]',
#                                                                      'add_414[0][0]']
#
#  depthwise_conv2d_123 (Dept  (None, 16, 16, 256)          6656      ['add_407[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_125 (Dept  (None, 16, 16, 256)          6656      ['add_415[0][0]']
#  hwiseConv2D)
#
#  activation_248 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_123[0][0]']
#  )
#
#  activation_252 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_125[0][0]']
#  )
#
#  batch_normalization_248 (B  (None, 16, 16, 256)          1024      ['activation_248[0][0]']
#  atchNormalization)
#
#  batch_normalization_252 (B  (None, 16, 16, 256)          1024      ['activation_252[0][0]']
#  atchNormalization)
#
#  add_408 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_248[0][0
#                                                                     ]',
#                                                                      'add_407[0][0]']
#
#  add_417 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_252[0][0
#                                                                     ]',
#                                                                      'add_415[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 16, 16, 256)          65792     ['add_408[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 16, 16, 256)          65792     ['add_417[0][0]']
#
#  activation_249 (Activation  (None, 16, 16, 256)          0         ['conv2d_125[0][0]']
#  )
#
#  activation_253 (Activation  (None, 16, 16, 256)          0         ['conv2d_127[0][0]']
#  )
#
#  batch_normalization_249 (B  (None, 16, 16, 256)          1024      ['activation_249[0][0]']
#  atchNormalization)
#
#  batch_normalization_253 (B  (None, 16, 16, 256)          1024      ['activation_253[0][0]']
#  atchNormalization)
#
#  add_409 (Add)               (None, 16, 16, 256)          0         ['add_393[0][0]',
#                                                                      'batch_normalization_249[0][0
#                                                                     ]']
#
#  add_418 (Add)               (None, 16, 16, 256)          0         ['add_402[0][0]',
#                                                                      'batch_normalization_253[0][0
#                                                                     ]']
#
#  add_410 (Add)               (None, 16, 16, 256)          0         ['add_351[0][0]',
#                                                                      'add_409[0][0]']
#
#  add_419 (Add)               (None, 16, 16, 256)          0         ['add_360[0][0]',
#                                                                      'add_418[0][0]']
#
#  add_420 (Add)               (None, 16, 16, 256)          0         ['add_410[0][0]',
#                                                                      'add_419[0][0]']
#
#  depthwise_conv2d_126 (Dept  (None, 16, 16, 256)          6656      ['add_420[0][0]']
#  hwiseConv2D)
#
#  activation_254 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_126[0][0]']
#  )
#
#  batch_normalization_254 (B  (None, 16, 16, 256)          1024      ['activation_254[0][0]']
#  atchNormalization)
#
#  add_422 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_254[0][0
#                                                                     ]',
#                                                                      'add_420[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 16, 16, 256)          65792     ['add_422[0][0]']
#
#  activation_255 (Activation  (None, 16, 16, 256)          0         ['conv2d_128[0][0]']
#  )
#
#  batch_normalization_255 (B  (None, 16, 16, 256)          1024      ['activation_255[0][0]']
#  atchNormalization)
#
#  add_423 (Add)               (None, 16, 16, 256)          0         ['add_407[0][0]',
#                                                                      'batch_normalization_255[0][0
#                                                                     ]']
#
#  add_424 (Add)               (None, 16, 16, 256)          0         ['add_365[0][0]',
#                                                                      'add_423[0][0]']
#
#  depthwise_conv2d_127 (Dept  (None, 16, 16, 256)          6656      ['add_424[0][0]']
#  hwiseConv2D)
#
#  activation_256 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_127[0][0]']
#  )
#
#  batch_normalization_256 (B  (None, 16, 16, 256)          1024      ['activation_256[0][0]']
#  atchNormalization)
#
#  add_425 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_256[0][0
#                                                                     ]',
#                                                                      'add_424[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 16, 16, 256)          65792     ['add_425[0][0]']
#
#  activation_257 (Activation  (None, 16, 16, 256)          0         ['conv2d_129[0][0]']
#  )
#
#  batch_normalization_257 (B  (None, 16, 16, 256)          1024      ['activation_257[0][0]']
#  atchNormalization)
#
#  add_426 (Add)               (None, 16, 16, 256)          0         ['add_410[0][0]',
#                                                                      'batch_normalization_257[0][0
#                                                                     ]']
#
#  add_427 (Add)               (None, 16, 16, 256)          0         ['add_368[0][0]',
#                                                                      'add_426[0][0]']
#
#  global_average_pooling2d_1  (None, 256)                  0         ['add_427[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 3)                    771       ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 5359619 (20.45 MB)
# Trainable params: 5293571 (20.19 MB)
# Non-trainable params: 66048 (258.00 KB)
# __________________________________________________________________________________________________

# %%
history, model = run_experiment(model)
# Out:
# Epoch 1/20
# 2/2 - 55s - loss: 4101.7017 - mean_squared_error: 4101.7017 - val_loss: 5578.7480 - val_mean_squared_error: 5578.7480 - 55s/epoch - 28s/step
# Epoch 2/20
# 2/2 - 5s - loss: 3789.8979 - mean_squared_error: 3789.8979 - val_loss: 11696.2314 - val_mean_squared_error: 11696.2314 - 5s/epoch - 3s/step
# Epoch 3/20
# 2/2 - 6s - loss: 3667.5864 - mean_squared_error: 3667.5864 - val_loss: 4944.4336 - val_mean_squared_error: 4944.4336 - 6s/epoch - 3s/step
# Epoch 4/20
# 2/2 - 6s - loss: 3882.1160 - mean_squared_error: 3882.1160 - val_loss: 12881.6553 - val_mean_squared_error: 12881.6553 - 6s/epoch - 3s/step
# Epoch 5/20
# 2/2 - 6s - loss: 3630.9351 - mean_squared_error: 3630.9351 - val_loss: 27329.5098 - val_mean_squared_error: 27329.5098 - 6s/epoch - 3s/step
# Epoch 6/20
# 2/2 - 5s - loss: 3403.1433 - mean_squared_error: 3403.1433 - val_loss: 28115.5566 - val_mean_squared_error: 28115.5566 - 5s/epoch - 3s/step
# Epoch 7/20
# 2/2 - 7s - loss: 3195.5737 - mean_squared_error: 3195.5737 - val_loss: 51665.5469 - val_mean_squared_error: 51665.5469 - 7s/epoch - 3s/step
# Epoch 8/20
# 2/2 - 5s - loss: 3004.4839 - mean_squared_error: 3004.4839 - val_loss: 72906.3203 - val_mean_squared_error: 72906.3203 - 5s/epoch - 3s/step
# Epoch 9/20
# 2/2 - 6s - loss: 2671.5703 - mean_squared_error: 2671.5703 - val_loss: 98949.2188 - val_mean_squared_error: 98949.2188 - 6s/epoch - 3s/step
# Epoch 10/20
# 2/2 - 6s - loss: 2393.5649 - mean_squared_error: 2393.5649 - val_loss: 93066.1250 - val_mean_squared_error: 93066.1250 - 6s/epoch - 3s/step
# Epoch 11/20
# 2/2 - 6s - loss: 2483.8704 - mean_squared_error: 2483.8704 - val_loss: 88435.5078 - val_mean_squared_error: 88435.5078 - 6s/epoch - 3s/step
# Epoch 12/20
# 2/2 - 6s - loss: 2180.5974 - mean_squared_error: 2180.5974 - val_loss: 55449.7617 - val_mean_squared_error: 55449.7617 - 6s/epoch - 3s/step
# Epoch 13/20
# 2/2 - 6s - loss: 2282.6768 - mean_squared_error: 2282.6768 - val_loss: 22776.7188 - val_mean_squared_error: 22776.7188 - 6s/epoch - 3s/step
# Epoch 14/20
# 2/2 - 6s - loss: 2023.6827 - mean_squared_error: 2023.6827 - val_loss: 14999.0596 - val_mean_squared_error: 14999.0596 - 6s/epoch - 3s/step
# Epoch 15/20
# 2/2 - 8s - loss: 1607.7539 - mean_squared_error: 1607.7539 - val_loss: 11208.8818 - val_mean_squared_error: 11208.8818 - 8s/epoch - 4s/step
# Epoch 16/20
# 2/2 - 8s - loss: 2055.3013 - mean_squared_error: 2055.3013 - val_loss: 8389.1250 - val_mean_squared_error: 8389.1250 - 8s/epoch - 4s/step
# Epoch 17/20
# 2/2 - 7s - loss: 1935.9283 - mean_squared_error: 1935.9283 - val_loss: 5862.4712 - val_mean_squared_error: 5862.4712 - 7s/epoch - 3s/step
# Epoch 18/20
# 2/2 - 5s - loss: 1907.0996 - mean_squared_error: 1907.0996 - val_loss: 3323.5222 - val_mean_squared_error: 3323.5222 - 5s/epoch - 3s/step
# Epoch 19/20
# 2/2 - 9s - loss: 1650.0764 - mean_squared_error: 1650.0764 - val_loss: 1608.4513 - val_mean_squared_error: 1608.4513 - 9s/epoch - 4s/step
# Epoch 20/20
# 2/2 - 10s - loss: 1445.9133 - mean_squared_error: 1445.9133 - val_loss: 1500.8453 - val_mean_squared_error: 1500.8453 - 10s/epoch - 5s/step
# 1/1 [==============================] - 1s 545ms/step - loss: 7358.3184 - mean_squared_error: 7358.3184
# Test error: 7358.32

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 6s 6s/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  9.33849777062734
# MSE:  155.74691112167287
# RMSE:  12.479860220438082
# r2_score:  -0.47610582985178085
# MSLE_min_shifted:  0.24951446500119823
# MAPE:  1.0581998048029354e+16
# ===== flank_wear results =====
# MAE:  103.62581380208333
# MSE:  20370.805191941083
# RMSE:  142.72632970808533
# r2_score:  -0.271398902993242
# MSLE:  0.7306610114890102
# MAPE:  0.6648859513164477
# ===== overhang results =====
# MAE:  38.38776173909505
# MSE:  1548.3990100399878
# RMSE:  39.34970152415375
# r2_score:  -75.75804033418426
# MSLE:  1.9987699902254727
# MAPE:  3.5703086232138097
# ===== multi results =====
# MAE:  50.45069110393524
# MSE:  7358.3170377009155
# RMSE:  64.85196381755905
# r2_score:  -25.501848355676426
# MSLE_min_shifted:  2.3162378986222967
# MAPE:  3527332682676452.5
