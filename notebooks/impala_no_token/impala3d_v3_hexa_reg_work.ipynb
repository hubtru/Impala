# %%
# !pip install tensorflow_addons

# clone Impala repository, refresh folder to see the Imapala repository
# runtime -> change runtime -> choose a gpu/tpu
# !git clone https://github.com/hubtru/Impala
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# fatal: destination path 'Impala' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras as k
from keras import layers
from sklearn.model_selection import train_test_split
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
# ============================== gpu info ==============================
print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
print("GPUs: ", tf.config.list_physical_devices("GPU"))
# Out:
# Num GPUs Available:  0
# GPUs:  []

# %%
# ============================== variables ==============================
# architecture
image_size = 256
filters = 256
depth = 4
columns = 4
widths = 4
kernel_size = 5
patch_size = 16
num_classes = 3

in_channel = 3
img_rows, img_cols = image_size, image_size
input_shape = (img_rows, img_cols, in_channel)

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 8
epochs = 20

# %%
# ============================== paths ==============================
# needed for generate_data
modality = "work"
exp_name = f"impala3d_v3_hexa_reg"
model_name = f"{exp_name}_{modality}"
model_save_path = f"{model_name}.h5"

# dataset
csv_path = "/content/Impala/dataset/labels_reg_sample.csv"
work_path = f"/content/Impala/dataset/{modality}"

# %%
# ============================== load/prepare dataset ==============================
df = pd.read_csv(csv_path)

# RANDOM DATASET: we switch to toolbased
# shuffle, need same state for tool/spec/chips/multi
np.random.seed(55)
df = df.iloc[np.random.permutation(len(df))]
# train/test/val : 70/15/15
train_df, test_df = train_test_split(df, test_size=0.3)
test_df, val_df = train_test_split(test_df, test_size=0.5)

print(
    "size check train/test/val",
    len(train_df),
    len(test_df),
    len(val_df),
    (len(train_df) + len(test_df) + len(val_df)),
)

train_df["work"] = train_df.id.map(lambda id: f"{work_path}/{id}.png")
test_df["work"] = test_df.id.map(lambda id: f"{work_path}/{id}.png")
val_df["work"] = val_df.id.map(lambda id: f"{work_path}/{id}.png")
# Out:
# size check train/test/val 14 3 3 20

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))
sns.histplot(train_df["gaps"], ax=ax[0])
sns.histplot(train_df["flank_wear"], ax=ax[1])
sns.histplot(train_df["overhang"], ax=ax[2])
ax[0].set_title("Label Distribution")
ax[1].set_title("Label Distribution")
ax[2].set_title("Label Distribution")
plt.show()

# %%
print("check if permutation is same on all models")
print("train_head", train_df.head())
print("test_head", test_df.head())
print("val_head", val_df.head())
# Out:
# check if permutation is same on all models
# train_head          id   gaps  flank_wear  overhang  \
# 14   T8R3B4   6.88       40.92     14.54
# 10   T6R9B3  12.94       95.63     16.65
# 0    T1R2B1   7.67       34.89     48.61
# 3   T2R13B4   0.00      122.59     25.55
# 1    T1R7B4  13.89       85.41     50.25
#
#                                         work
# 14   /content/Impala/dataset/work/T8R3B4.png
# 10   /content/Impala/dataset/work/T6R9B3.png
# 0    /content/Impala/dataset/work/T1R2B1.png
# 3   /content/Impala/dataset/work/T2R13B4.png
# 1    /content/Impala/dataset/work/T1R7B4.png
# test_head          id   gaps  flank_wear  overhang  \
# 16   T9R7B4   0.00       94.62     17.05
# 18  T10R3B4   0.00       44.26      7.10
# 9   T5R12B1  21.79      334.39     16.14
#
#                                         work
# 16   /content/Impala/dataset/work/T9R7B4.png
# 18  /content/Impala/dataset/work/T10R3B4.png
# 9   /content/Impala/dataset/work/T5R12B1.png
# val_head          id   gaps  flank_wear  overhang  \
# 5   T3R10B1   5.00      128.39     35.26
# 13  T7R14B3  13.67      141.91     14.62
# 12   T7R8B3   7.45       77.05     19.02
#
#                                         work
# 5   /content/Impala/dataset/work/T3R10B1.png
# 13  /content/Impala/dataset/work/T7R14B3.png
# 12   /content/Impala/dataset/work/T7R8B3.png

# %%
def read_tools(file_paths, img_rows, img_cols, channels):
    """
    Reads the spectogram files from disk and normalizes the pixel values
      @params:
        file_paths - Array of file paths to read from
        img_rows - The image height.
        img_cols - The image width.
        as_grey - Read the image as Greyscale or RGB.
        channels - Number of channels.
      @returns:
        The created and compiled model (Model)
    """
    images = []

    for file_path in file_paths:
        img = cv2.imread(file_path)
        res = cv2.resize(img, dsize=(img_rows, img_cols), interpolation=cv2.INTER_CUBIC)
        images.append(res)

    images = np.asarray(images, dtype=np.float32)

    # normalize
    images = images / np.max(images)

    # reshape to match Keras expectaions
    images = images.reshape(images.shape[0], img_rows, img_cols, channels)

    return images

# %%
x_train_work = read_tools(train_df.work.values, img_rows, img_cols, in_channel)
x_test_work = read_tools(test_df.work.values, img_rows, img_cols, in_channel)
x_val_work = read_tools(val_df.work.values, img_rows, img_cols, in_channel)

# %%
x_train_work.shape
# Out:
# (14, 256, 256, 3)

# %%
pil_img = tf.keras.utils.array_to_img(x_train_work[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
labels_train = train_df[["gaps", "flank_wear", "overhang"]]
labels_test = test_df[["gaps", "flank_wear", "overhang"]]
labels_val = val_df[["gaps", "flank_wear", "overhang"]]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_work, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_work, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_work, labels_val))

# %%
# ============================== augment ==============================
auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [
        k.layers.RandomBrightness(factor=(-0.2, 0.2), value_range=(0, 1)),
        k.layers.RandomContrast(factor=0.2),
        k.layers.GaussianNoise(stddev=0.2),
    ],
    name="data_augmentation",
)

# %%
def generate_datasets(images, is_train=False, shuffle=False):
    dataset = images
    if shuffle:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

# %%
train_ds = generate_datasets(train_dataset, is_train=True, shuffle=True)
val_ds = generate_datasets(val_dataset)
test_ds = generate_datasets(test_dataset)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float64, name=None))>

# %%
# ============================== build model ==============================
def activation_block(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def conv_stem(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_block(x)


def conv_mixer_block(
    x, pe_block, column, level, depth, width, r_arr, filters: int, kernel_size: int
):
    if column == 0:
        # Depthwise convolution.
        x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
        x = layers.Add()([activation_block(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_block(x)

        if width != 0:
            x0 = fusion_block_double(r_arr[width - 1][column][level], x0)

        r_arr = reverasable_output_array(x, r_arr, width, column, level)
        return x, r_arr
    elif column != 0:
        if level == 0:
            x0 = fusion_block_double(r_arr[width][column - 1][level + 1], pe_block)
        elif level <= depth - 2:
            x0 = fusion_block_double(r_arr[width][column - 1][level + 1], x)
            if width != 0:
                x = fusion_block_double(r_arr[width - 1][column - 1][level + 1], x)
        else:
            x0 = x
        x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x0)
        x = layers.Add()([activation_block(x), x0])  # Residual.

        # Pointwise convolution.
        x = layers.Conv2D(filters, kernel_size=1)(x)
        x = activation_block(x)

        x = fusion_block_double(r_arr[width][column - 1][level], x)
        if width != 0:
            x = fusion_block_double(r_arr[width - 1][column][level], x)

        r_arr = reverasable_output_array(x, r_arr, width, column, level)

        return x, r_arr

    return x, r_arr


def fusion_block_double(x, y):
    return layers.Add()([x, y])


def reverasable_output_array(x, r_arr, width, column, level):
    r_arr[width][column][level] = x
    return r_arr


def get_conv_mixer_256_8(
    image_size=image_size,
    filters=filters,
    depth=depth,
    columns=columns,
    width=widths,
    kernel_size=kernel_size,
    patch_size=patch_size,
    num_classes=num_classes,
):
    r_arr = [
        [[None for _ in range(depth)] for _ in range(columns)] for _ in range(width)
    ]

    inputs = k.Input(input_shape)
    # x = layers.Rescaling(scale=1.0 / 255)(inputs)         # already rescaled

    # Extract patch embeddings.
    x = conv_stem(inputs, filters, patch_size)
    pe_block = x

    # ConvMixer blocks.
    for w in range(width):
        for column in range(columns):
            for level in range(depth):
                x, r_arr = conv_mixer_block(
                    x, pe_block, column, level, depth, w, r_arr, filters, kernel_size
                )

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="linear")(x)

    return k.Model(inputs, outputs)

# %%
# ============================== run experiment ==============================
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.MeanSquaredError()]
    )

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        verbose=2,
    )

    _, accuracy = model.evaluate(test_ds)
    print(f"Test error: {round(accuracy, 2)}")

    return history, model

# %%
model = get_conv_mixer_256_8()
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_260 (Conv2D)         (None, 16, 16, 256)          196864    ['input_5[0][0]']
#
#  activation_516 (Activation  (None, 16, 16, 256)          0         ['conv2d_260[0][0]']
#  )
#
#  batch_normalization_516 (B  (None, 16, 16, 256)          1024      ['activation_516[0][0]']
#  atchNormalization)
#
#  depthwise_conv2d_256 (Dept  (None, 16, 16, 256)          6656      ['batch_normalization_516[0][0
#  hwiseConv2D)                                                       ]']
#
#  activation_517 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_256[0][0]']
#  )
#
#  batch_normalization_517 (B  (None, 16, 16, 256)          1024      ['activation_517[0][0]']
#  atchNormalization)
#
#  add_856 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_517[0][0
#                                                                     ]',
#                                                                      'batch_normalization_516[0][0
#                                                                     ]']
#
#  conv2d_261 (Conv2D)         (None, 16, 16, 256)          65792     ['add_856[0][0]']
#
#  activation_518 (Activation  (None, 16, 16, 256)          0         ['conv2d_261[0][0]']
#  )
#
#  batch_normalization_518 (B  (None, 16, 16, 256)          1024      ['activation_518[0][0]']
#  atchNormalization)
#
#  depthwise_conv2d_257 (Dept  (None, 16, 16, 256)          6656      ['batch_normalization_518[0][0
#  hwiseConv2D)                                                       ]']
#
#  activation_519 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_257[0][0]']
#  )
#
#  batch_normalization_519 (B  (None, 16, 16, 256)          1024      ['activation_519[0][0]']
#  atchNormalization)
#
#  add_857 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_519[0][0
#                                                                     ]',
#                                                                      'batch_normalization_518[0][0
#                                                                     ]']
#
#  conv2d_262 (Conv2D)         (None, 16, 16, 256)          65792     ['add_857[0][0]']
#
#  activation_520 (Activation  (None, 16, 16, 256)          0         ['conv2d_262[0][0]']
#  )
#
#  batch_normalization_520 (B  (None, 16, 16, 256)          1024      ['activation_520[0][0]']
#  atchNormalization)
#
#  add_860 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_520[0][0
#                                                                     ]',
#                                                                      'batch_normalization_516[0][0
#                                                                     ]']
#
#  depthwise_conv2d_260 (Dept  (None, 16, 16, 256)          6656      ['add_860[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_258 (Dept  (None, 16, 16, 256)          6656      ['batch_normalization_520[0][0
#  hwiseConv2D)                                                       ]']
#
#  activation_525 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_260[0][0]']
#  )
#
#  activation_521 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_258[0][0]']
#  )
#
#  batch_normalization_525 (B  (None, 16, 16, 256)          1024      ['activation_525[0][0]']
#  atchNormalization)
#
#  batch_normalization_521 (B  (None, 16, 16, 256)          1024      ['activation_521[0][0]']
#  atchNormalization)
#
#  add_861 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_525[0][0
#                                                                     ]',
#                                                                      'add_860[0][0]']
#
#  add_858 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_521[0][0
#                                                                     ]',
#                                                                      'batch_normalization_520[0][0
#                                                                     ]']
#
#  conv2d_265 (Conv2D)         (None, 16, 16, 256)          65792     ['add_861[0][0]']
#
#  conv2d_263 (Conv2D)         (None, 16, 16, 256)          65792     ['add_858[0][0]']
#
#  activation_526 (Activation  (None, 16, 16, 256)          0         ['conv2d_265[0][0]']
#  )
#
#  activation_522 (Activation  (None, 16, 16, 256)          0         ['conv2d_263[0][0]']
#  )
#
#  batch_normalization_526 (B  (None, 16, 16, 256)          1024      ['activation_526[0][0]']
#  atchNormalization)
#
#  batch_normalization_522 (B  (None, 16, 16, 256)          1024      ['activation_522[0][0]']
#  atchNormalization)
#
#  add_862 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_518[0][0
#                                                                     ]',
#                                                                      'batch_normalization_526[0][0
#                                                                     ]']
#
#  add_863 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_522[0][0
#                                                                     ]',
#                                                                      'add_862[0][0]']
#
#  depthwise_conv2d_261 (Dept  (None, 16, 16, 256)          6656      ['add_863[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_259 (Dept  (None, 16, 16, 256)          6656      ['batch_normalization_522[0][0
#  hwiseConv2D)                                                       ]']
#
#  activation_527 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_261[0][0]']
#  )
#
#  activation_523 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_259[0][0]']
#  )
#
#  batch_normalization_527 (B  (None, 16, 16, 256)          1024      ['activation_527[0][0]']
#  atchNormalization)
#
#  batch_normalization_523 (B  (None, 16, 16, 256)          1024      ['activation_523[0][0]']
#  atchNormalization)
#
#  add_864 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_527[0][0
#                                                                     ]',
#                                                                      'add_863[0][0]']
#
#  add_859 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_523[0][0
#                                                                     ]',
#                                                                      'batch_normalization_522[0][0
#                                                                     ]']
#
#  conv2d_266 (Conv2D)         (None, 16, 16, 256)          65792     ['add_864[0][0]']
#
#  conv2d_264 (Conv2D)         (None, 16, 16, 256)          65792     ['add_859[0][0]']
#
#  activation_528 (Activation  (None, 16, 16, 256)          0         ['conv2d_266[0][0]']
#  )
#
#  activation_524 (Activation  (None, 16, 16, 256)          0         ['conv2d_264[0][0]']
#  )
#
#  batch_normalization_528 (B  (None, 16, 16, 256)          1024      ['activation_528[0][0]']
#  atchNormalization)
#
#  batch_normalization_524 (B  (None, 16, 16, 256)          1024      ['activation_524[0][0]']
#  atchNormalization)
#
#  add_865 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_520[0][0
#                                                                     ]',
#                                                                      'batch_normalization_528[0][0
#                                                                     ]']
#
#  add_866 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_524[0][0
#                                                                     ]',
#                                                                      'add_865[0][0]']
#
#  add_871 (Add)               (None, 16, 16, 256)          0         ['add_865[0][0]',
#                                                                      'batch_normalization_516[0][0
#                                                                     ]']
#
#  depthwise_conv2d_262 (Dept  (None, 16, 16, 256)          6656      ['add_866[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_264 (Dept  (None, 16, 16, 256)          6656      ['add_871[0][0]']
#  hwiseConv2D)
#
#  activation_529 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_262[0][0]']
#  )
#
#  activation_533 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_264[0][0]']
#  )
#
#  batch_normalization_529 (B  (None, 16, 16, 256)          1024      ['activation_529[0][0]']
#  atchNormalization)
#
#  batch_normalization_533 (B  (None, 16, 16, 256)          1024      ['activation_533[0][0]']
#  atchNormalization)
#
#  add_867 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_529[0][0
#                                                                     ]',
#                                                                      'add_866[0][0]']
#
#  add_872 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_533[0][0
#                                                                     ]',
#                                                                      'add_871[0][0]']
#
#  conv2d_267 (Conv2D)         (None, 16, 16, 256)          65792     ['add_867[0][0]']
#
#  conv2d_269 (Conv2D)         (None, 16, 16, 256)          65792     ['add_872[0][0]']
#
#  activation_530 (Activation  (None, 16, 16, 256)          0         ['conv2d_267[0][0]']
#  )
#
#  activation_534 (Activation  (None, 16, 16, 256)          0         ['conv2d_269[0][0]']
#  )
#
#  batch_normalization_530 (B  (None, 16, 16, 256)          1024      ['activation_530[0][0]']
#  atchNormalization)
#
#  batch_normalization_534 (B  (None, 16, 16, 256)          1024      ['activation_534[0][0]']
#  atchNormalization)
#
#  add_868 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_522[0][0
#                                                                     ]',
#                                                                      'batch_normalization_530[0][0
#                                                                     ]']
#
#  add_873 (Add)               (None, 16, 16, 256)          0         ['add_862[0][0]',
#                                                                      'batch_normalization_534[0][0
#                                                                     ]']
#
#  add_874 (Add)               (None, 16, 16, 256)          0         ['add_868[0][0]',
#                                                                      'add_873[0][0]']
#
#  depthwise_conv2d_263 (Dept  (None, 16, 16, 256)          6656      ['add_868[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_265 (Dept  (None, 16, 16, 256)          6656      ['add_874[0][0]']
#  hwiseConv2D)
#
#  activation_531 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_263[0][0]']
#  )
#
#  activation_535 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_265[0][0]']
#  )
#
#  batch_normalization_531 (B  (None, 16, 16, 256)          1024      ['activation_531[0][0]']
#  atchNormalization)
#
#  batch_normalization_535 (B  (None, 16, 16, 256)          1024      ['activation_535[0][0]']
#  atchNormalization)
#
#  add_869 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_531[0][0
#                                                                     ]',
#                                                                      'add_868[0][0]']
#
#  add_875 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_535[0][0
#                                                                     ]',
#                                                                      'add_874[0][0]']
#
#  conv2d_268 (Conv2D)         (None, 16, 16, 256)          65792     ['add_869[0][0]']
#
#  conv2d_270 (Conv2D)         (None, 16, 16, 256)          65792     ['add_875[0][0]']
#
#  activation_532 (Activation  (None, 16, 16, 256)          0         ['conv2d_268[0][0]']
#  )
#
#  activation_536 (Activation  (None, 16, 16, 256)          0         ['conv2d_270[0][0]']
#  )
#
#  batch_normalization_532 (B  (None, 16, 16, 256)          1024      ['activation_532[0][0]']
#  atchNormalization)
#
#  batch_normalization_536 (B  (None, 16, 16, 256)          1024      ['activation_536[0][0]']
#  atchNormalization)
#
#  add_870 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_524[0][0
#                                                                     ]',
#                                                                      'batch_normalization_532[0][0
#                                                                     ]']
#
#  add_876 (Add)               (None, 16, 16, 256)          0         ['add_865[0][0]',
#                                                                      'batch_normalization_536[0][0
#                                                                     ]']
#
#  add_877 (Add)               (None, 16, 16, 256)          0         ['add_870[0][0]',
#                                                                      'add_876[0][0]']
#
#  add_882 (Add)               (None, 16, 16, 256)          0         ['add_876[0][0]',
#                                                                      'batch_normalization_516[0][0
#                                                                     ]']
#
#  depthwise_conv2d_266 (Dept  (None, 16, 16, 256)          6656      ['add_877[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_268 (Dept  (None, 16, 16, 256)          6656      ['add_882[0][0]']
#  hwiseConv2D)
#
#  activation_537 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_266[0][0]']
#  )
#
#  activation_541 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_268[0][0]']
#  )
#
#  batch_normalization_537 (B  (None, 16, 16, 256)          1024      ['activation_537[0][0]']
#  atchNormalization)
#
#  batch_normalization_541 (B  (None, 16, 16, 256)          1024      ['activation_541[0][0]']
#  atchNormalization)
#
#  add_878 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_537[0][0
#                                                                     ]',
#                                                                      'add_877[0][0]']
#
#  add_883 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_541[0][0
#                                                                     ]',
#                                                                      'add_882[0][0]']
#
#  conv2d_271 (Conv2D)         (None, 16, 16, 256)          65792     ['add_878[0][0]']
#
#  conv2d_273 (Conv2D)         (None, 16, 16, 256)          65792     ['add_883[0][0]']
#
#  activation_538 (Activation  (None, 16, 16, 256)          0         ['conv2d_271[0][0]']
#  )
#
#  activation_542 (Activation  (None, 16, 16, 256)          0         ['conv2d_273[0][0]']
#  )
#
#  batch_normalization_538 (B  (None, 16, 16, 256)          1024      ['activation_538[0][0]']
#  atchNormalization)
#
#  batch_normalization_542 (B  (None, 16, 16, 256)          1024      ['activation_542[0][0]']
#  atchNormalization)
#
#  add_879 (Add)               (None, 16, 16, 256)          0         ['add_868[0][0]',
#                                                                      'batch_normalization_538[0][0
#                                                                     ]']
#
#  add_884 (Add)               (None, 16, 16, 256)          0         ['add_873[0][0]',
#                                                                      'batch_normalization_542[0][0
#                                                                     ]']
#
#  add_885 (Add)               (None, 16, 16, 256)          0         ['add_879[0][0]',
#                                                                      'add_884[0][0]']
#
#  depthwise_conv2d_267 (Dept  (None, 16, 16, 256)          6656      ['add_879[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_269 (Dept  (None, 16, 16, 256)          6656      ['add_885[0][0]']
#  hwiseConv2D)
#
#  activation_539 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_267[0][0]']
#  )
#
#  activation_543 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_269[0][0]']
#  )
#
#  batch_normalization_539 (B  (None, 16, 16, 256)          1024      ['activation_539[0][0]']
#  atchNormalization)
#
#  batch_normalization_543 (B  (None, 16, 16, 256)          1024      ['activation_543[0][0]']
#  atchNormalization)
#
#  add_880 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_539[0][0
#                                                                     ]',
#                                                                      'add_879[0][0]']
#
#  add_886 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_543[0][0
#                                                                     ]',
#                                                                      'add_885[0][0]']
#
#  conv2d_272 (Conv2D)         (None, 16, 16, 256)          65792     ['add_880[0][0]']
#
#  conv2d_274 (Conv2D)         (None, 16, 16, 256)          65792     ['add_886[0][0]']
#
#  activation_540 (Activation  (None, 16, 16, 256)          0         ['conv2d_272[0][0]']
#  )
#
#  activation_544 (Activation  (None, 16, 16, 256)          0         ['conv2d_274[0][0]']
#  )
#
#  batch_normalization_540 (B  (None, 16, 16, 256)          1024      ['activation_540[0][0]']
#  atchNormalization)
#
#  batch_normalization_544 (B  (None, 16, 16, 256)          1024      ['activation_544[0][0]']
#  atchNormalization)
#
#  add_881 (Add)               (None, 16, 16, 256)          0         ['add_870[0][0]',
#                                                                      'batch_normalization_540[0][0
#                                                                     ]']
#
#  add_887 (Add)               (None, 16, 16, 256)          0         ['add_876[0][0]',
#                                                                      'batch_normalization_544[0][0
#                                                                     ]']
#
#  add_888 (Add)               (None, 16, 16, 256)          0         ['add_881[0][0]',
#                                                                      'add_887[0][0]']
#
#  depthwise_conv2d_270 (Dept  (None, 16, 16, 256)          6656      ['add_888[0][0]']
#  hwiseConv2D)
#
#  activation_545 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_270[0][0]']
#  )
#
#  batch_normalization_545 (B  (None, 16, 16, 256)          1024      ['activation_545[0][0]']
#  atchNormalization)
#
#  add_889 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_545[0][0
#                                                                     ]',
#                                                                      'add_888[0][0]']
#
#  conv2d_275 (Conv2D)         (None, 16, 16, 256)          65792     ['add_889[0][0]']
#
#  activation_546 (Activation  (None, 16, 16, 256)          0         ['conv2d_275[0][0]']
#  )
#
#  batch_normalization_546 (B  (None, 16, 16, 256)          1024      ['activation_546[0][0]']
#  atchNormalization)
#
#  add_890 (Add)               (None, 16, 16, 256)          0         ['add_879[0][0]',
#                                                                      'batch_normalization_546[0][0
#                                                                     ]']
#
#  depthwise_conv2d_271 (Dept  (None, 16, 16, 256)          6656      ['add_890[0][0]']
#  hwiseConv2D)
#
#  activation_547 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_271[0][0]']
#  )
#
#  batch_normalization_547 (B  (None, 16, 16, 256)          1024      ['activation_547[0][0]']
#  atchNormalization)
#
#  add_891 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_547[0][0
#                                                                     ]',
#                                                                      'add_890[0][0]']
#
#  conv2d_276 (Conv2D)         (None, 16, 16, 256)          65792     ['add_891[0][0]']
#
#  activation_548 (Activation  (None, 16, 16, 256)          0         ['conv2d_276[0][0]']
#  )
#
#  batch_normalization_548 (B  (None, 16, 16, 256)          1024      ['activation_548[0][0]']
#  atchNormalization)
#
#  add_892 (Add)               (None, 16, 16, 256)          0         ['add_881[0][0]',
#                                                                      'batch_normalization_548[0][0
#                                                                     ]']
#
#  depthwise_conv2d_272 (Dept  (None, 16, 16, 256)          6656      ['add_892[0][0]']
#  hwiseConv2D)
#
#  activation_549 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_272[0][0]']
#  )
#
#  batch_normalization_549 (B  (None, 16, 16, 256)          1024      ['activation_549[0][0]']
#  atchNormalization)
#
#  add_893 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_549[0][0
#                                                                     ]',
#                                                                      'add_892[0][0]']
#
#  conv2d_277 (Conv2D)         (None, 16, 16, 256)          65792     ['add_893[0][0]']
#
#  activation_550 (Activation  (None, 16, 16, 256)          0         ['conv2d_277[0][0]']
#  )
#
#  batch_normalization_550 (B  (None, 16, 16, 256)          1024      ['activation_550[0][0]']
#  atchNormalization)
#
#  depthwise_conv2d_273 (Dept  (None, 16, 16, 256)          6656      ['batch_normalization_550[0][0
#  hwiseConv2D)                                                       ]']
#
#  activation_551 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_273[0][0]']
#  )
#
#  batch_normalization_551 (B  (None, 16, 16, 256)          1024      ['activation_551[0][0]']
#  atchNormalization)
#
#  add_895 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_551[0][0
#                                                                     ]',
#                                                                      'batch_normalization_550[0][0
#                                                                     ]']
#
#  conv2d_278 (Conv2D)         (None, 16, 16, 256)          65792     ['add_895[0][0]']
#
#  activation_552 (Activation  (None, 16, 16, 256)          0         ['conv2d_278[0][0]']
#  )
#
#  batch_normalization_552 (B  (None, 16, 16, 256)          1024      ['activation_552[0][0]']
#  atchNormalization)
#
#  add_901 (Add)               (None, 16, 16, 256)          0         ['batch_normalization_552[0][0
#                                                                     ]',
#                                                                      'batch_normalization_516[0][0
# ...
#  add_1054 (Add)              (None, 16, 16, 256)          0         ['batch_normalization_637[0][0
#                                                                     ]',
#                                                                      'add_1053[0][0]']
#
#  conv2d_319 (Conv2D)         (None, 16, 16, 256)          65792     ['add_1047[0][0]']
#
#  conv2d_321 (Conv2D)         (None, 16, 16, 256)          65792     ['add_1054[0][0]']
#
#  activation_634 (Activation  (None, 16, 16, 256)          0         ['conv2d_319[0][0]']
#  )
#
#  activation_638 (Activation  (None, 16, 16, 256)          0         ['conv2d_321[0][0]']
#  )
#
#  batch_normalization_634 (B  (None, 16, 16, 256)          1024      ['activation_634[0][0]']
#  atchNormalization)
#
#  batch_normalization_638 (B  (None, 16, 16, 256)          1024      ['activation_638[0][0]']
#  atchNormalization)
#
#  add_1048 (Add)              (None, 16, 16, 256)          0         ['add_1032[0][0]',
#                                                                      'batch_normalization_634[0][0
#                                                                     ]']
#
#  add_1055 (Add)              (None, 16, 16, 256)          0         ['add_1039[0][0]',
#                                                                      'batch_normalization_638[0][0
#                                                                     ]']
#
#  add_1049 (Add)              (None, 16, 16, 256)          0         ['add_990[0][0]',
#                                                                      'add_1048[0][0]']
#
#  add_1056 (Add)              (None, 16, 16, 256)          0         ['add_997[0][0]',
#                                                                      'add_1055[0][0]']
#
#  add_1057 (Add)              (None, 16, 16, 256)          0         ['add_1049[0][0]',
#                                                                      'add_1056[0][0]']
#
#  depthwise_conv2d_315 (Dept  (None, 16, 16, 256)          6656      ['add_1049[0][0]']
#  hwiseConv2D)
#
#  depthwise_conv2d_317 (Dept  (None, 16, 16, 256)          6656      ['add_1057[0][0]']
#  hwiseConv2D)
#
#  activation_635 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_315[0][0]']
#  )
#
#  activation_639 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_317[0][0]']
#  )
#
#  batch_normalization_635 (B  (None, 16, 16, 256)          1024      ['activation_635[0][0]']
#  atchNormalization)
#
#  batch_normalization_639 (B  (None, 16, 16, 256)          1024      ['activation_639[0][0]']
#  atchNormalization)
#
#  add_1050 (Add)              (None, 16, 16, 256)          0         ['batch_normalization_635[0][0
#                                                                     ]',
#                                                                      'add_1049[0][0]']
#
#  add_1059 (Add)              (None, 16, 16, 256)          0         ['batch_normalization_639[0][0
#                                                                     ]',
#                                                                      'add_1057[0][0]']
#
#  conv2d_320 (Conv2D)         (None, 16, 16, 256)          65792     ['add_1050[0][0]']
#
#  conv2d_322 (Conv2D)         (None, 16, 16, 256)          65792     ['add_1059[0][0]']
#
#  activation_636 (Activation  (None, 16, 16, 256)          0         ['conv2d_320[0][0]']
#  )
#
#  activation_640 (Activation  (None, 16, 16, 256)          0         ['conv2d_322[0][0]']
#  )
#
#  batch_normalization_636 (B  (None, 16, 16, 256)          1024      ['activation_636[0][0]']
#  atchNormalization)
#
#  batch_normalization_640 (B  (None, 16, 16, 256)          1024      ['activation_640[0][0]']
#  atchNormalization)
#
#  add_1051 (Add)              (None, 16, 16, 256)          0         ['add_1035[0][0]',
#                                                                      'batch_normalization_636[0][0
#                                                                     ]']
#
#  add_1060 (Add)              (None, 16, 16, 256)          0         ['add_1044[0][0]',
#                                                                      'batch_normalization_640[0][0
#                                                                     ]']
#
#  add_1052 (Add)              (None, 16, 16, 256)          0         ['add_993[0][0]',
#                                                                      'add_1051[0][0]']
#
#  add_1061 (Add)              (None, 16, 16, 256)          0         ['add_1002[0][0]',
#                                                                      'add_1060[0][0]']
#
#  add_1062 (Add)              (None, 16, 16, 256)          0         ['add_1052[0][0]',
#                                                                      'add_1061[0][0]']
#
#  depthwise_conv2d_318 (Dept  (None, 16, 16, 256)          6656      ['add_1062[0][0]']
#  hwiseConv2D)
#
#  activation_641 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_318[0][0]']
#  )
#
#  batch_normalization_641 (B  (None, 16, 16, 256)          1024      ['activation_641[0][0]']
#  atchNormalization)
#
#  add_1064 (Add)              (None, 16, 16, 256)          0         ['batch_normalization_641[0][0
#                                                                     ]',
#                                                                      'add_1062[0][0]']
#
#  conv2d_323 (Conv2D)         (None, 16, 16, 256)          65792     ['add_1064[0][0]']
#
#  activation_642 (Activation  (None, 16, 16, 256)          0         ['conv2d_323[0][0]']
#  )
#
#  batch_normalization_642 (B  (None, 16, 16, 256)          1024      ['activation_642[0][0]']
#  atchNormalization)
#
#  add_1065 (Add)              (None, 16, 16, 256)          0         ['add_1049[0][0]',
#                                                                      'batch_normalization_642[0][0
#                                                                     ]']
#
#  add_1066 (Add)              (None, 16, 16, 256)          0         ['add_1007[0][0]',
#                                                                      'add_1065[0][0]']
#
#  depthwise_conv2d_319 (Dept  (None, 16, 16, 256)          6656      ['add_1066[0][0]']
#  hwiseConv2D)
#
#  activation_643 (Activation  (None, 16, 16, 256)          0         ['depthwise_conv2d_319[0][0]']
#  )
#
#  batch_normalization_643 (B  (None, 16, 16, 256)          1024      ['activation_643[0][0]']
#  atchNormalization)
#
#  add_1067 (Add)              (None, 16, 16, 256)          0         ['batch_normalization_643[0][0
#                                                                     ]',
#                                                                      'add_1066[0][0]']
#
#  conv2d_324 (Conv2D)         (None, 16, 16, 256)          65792     ['add_1067[0][0]']
#
#  activation_644 (Activation  (None, 16, 16, 256)          0         ['conv2d_324[0][0]']
#  )
#
#  batch_normalization_644 (B  (None, 16, 16, 256)          1024      ['activation_644[0][0]']
#  atchNormalization)
#
#  add_1068 (Add)              (None, 16, 16, 256)          0         ['add_1052[0][0]',
#                                                                      'batch_normalization_644[0][0
#                                                                     ]']
#
#  add_1069 (Add)              (None, 16, 16, 256)          0         ['add_1010[0][0]',
#                                                                      'add_1068[0][0]']
#
#  global_average_pooling2d_4  (None, 256)                  0         ['add_1069[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 3)                    771       ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 4966403 (18.95 MB)
# Trainable params: 4900355 (18.69 MB)
# Non-trainable params: 66048 (258.00 KB)
# __________________________________________________________________________________________________

# %%
history, model = run_experiment(model)
# Out:
# Epoch 1/20
# 2/2 - 86s - loss: 4256.6943 - mean_squared_error: 4256.6943 - val_loss: 4092.8445 - val_mean_squared_error: 4092.8445 - 86s/epoch - 43s/step
# Epoch 2/20
# 2/2 - 6s - loss: 4893.2896 - mean_squared_error: 4893.2896 - val_loss: 4970.3413 - val_mean_squared_error: 4970.3413 - 6s/epoch - 3s/step
# Epoch 3/20
# 2/2 - 6s - loss: 3976.2539 - mean_squared_error: 3976.2539 - val_loss: 7967.7290 - val_mean_squared_error: 7967.7290 - 6s/epoch - 3s/step
# Epoch 4/20
# 2/2 - 5s - loss: 3490.5063 - mean_squared_error: 3490.5063 - val_loss: 18136.9863 - val_mean_squared_error: 18136.9863 - 5s/epoch - 3s/step
# Epoch 5/20
# 2/2 - 6s - loss: 3371.3801 - mean_squared_error: 3371.3801 - val_loss: 18427.7930 - val_mean_squared_error: 18427.7930 - 6s/epoch - 3s/step
# Epoch 6/20
# 2/2 - 6s - loss: 3643.6208 - mean_squared_error: 3643.6208 - val_loss: 20575.8203 - val_mean_squared_error: 20575.8203 - 6s/epoch - 3s/step
# Epoch 7/20
# 2/2 - 8s - loss: 3453.2595 - mean_squared_error: 3453.2595 - val_loss: 22906.5488 - val_mean_squared_error: 22906.5488 - 8s/epoch - 4s/step
# Epoch 8/20
# 2/2 - 5s - loss: 3037.2439 - mean_squared_error: 3037.2439 - val_loss: 20690.4629 - val_mean_squared_error: 20690.4629 - 5s/epoch - 3s/step
# Epoch 9/20
# 2/2 - 6s - loss: 2625.2065 - mean_squared_error: 2625.2065 - val_loss: 21825.6660 - val_mean_squared_error: 21825.6660 - 6s/epoch - 3s/step
# Epoch 10/20
# 2/2 - 5s - loss: 3393.5911 - mean_squared_error: 3393.5911 - val_loss: 16438.8223 - val_mean_squared_error: 16438.8223 - 5s/epoch - 3s/step
# Epoch 11/20
# 2/2 - 7s - loss: 2736.1626 - mean_squared_error: 2736.1626 - val_loss: 9156.0352 - val_mean_squared_error: 9156.0352 - 7s/epoch - 3s/step
# Epoch 12/20
# 2/2 - 6s - loss: 2407.8054 - mean_squared_error: 2407.8054 - val_loss: 7242.3687 - val_mean_squared_error: 7242.3687 - 6s/epoch - 3s/step
# Epoch 13/20
# 2/2 - 6s - loss: 2815.7239 - mean_squared_error: 2815.7239 - val_loss: 6347.1401 - val_mean_squared_error: 6347.1401 - 6s/epoch - 3s/step
# Epoch 14/20
# 2/2 - 6s - loss: 2586.3064 - mean_squared_error: 2586.3064 - val_loss: 4747.9419 - val_mean_squared_error: 4747.9419 - 6s/epoch - 3s/step
# Epoch 15/20
# 2/2 - 5s - loss: 2198.7561 - mean_squared_error: 2198.7561 - val_loss: 3597.5332 - val_mean_squared_error: 3597.5332 - 5s/epoch - 3s/step
# Epoch 16/20
# 2/2 - 5s - loss: 2239.8535 - mean_squared_error: 2239.8535 - val_loss: 2959.9656 - val_mean_squared_error: 2959.9656 - 5s/epoch - 3s/step
# Epoch 17/20
# 2/2 - 7s - loss: 2048.8704 - mean_squared_error: 2048.8704 - val_loss: 2710.1433 - val_mean_squared_error: 2710.1433 - 7s/epoch - 3s/step
# Epoch 18/20
# 2/2 - 5s - loss: 1812.8776 - mean_squared_error: 1812.8776 - val_loss: 2733.7136 - val_mean_squared_error: 2733.7136 - 5s/epoch - 3s/step
# Epoch 19/20
# 2/2 - 6s - loss: 1748.2012 - mean_squared_error: 1748.2012 - val_loss: 2473.9927 - val_mean_squared_error: 2473.9927 - 6s/epoch - 3s/step
# Epoch 20/20
# 2/2 - 8s - loss: 1443.4822 - mean_squared_error: 1443.4822 - val_loss: 2325.1887 - val_mean_squared_error: 2325.1887 - 8s/epoch - 4s/step
# 1/1 [==============================] - 0s 315ms/step - loss: 9197.2666 - mean_squared_error: 9197.2666
# Test error: 9197.27

# %%
model.save(model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 0s 324ms/step

# %%
# ============================== generate data ==============================
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import interp
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import PredictionErrorDisplay
from sklearn import metrics
import tensorflow as tf
from tensorflow import keras as k

# %%
multi_pred = pred
gaps_pred, flank_wear_pred, overhang_pred = multi_pred.T

multi_true = labels_test.to_numpy()
gaps_true, flank_wear_true, overhang_true = multi_true.T

# %%
labels_list = [
    "gaps",
    "flank_wear",
    "overhang",
    "multi",
]
pred_list = [
    gaps_pred,
    flank_wear_pred,
    overhang_pred,
    multi_pred,
]
true_list = [
    gaps_true,
    flank_wear_true,
    overhang_true,
    multi_true,
]

# %%
# loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    # https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.html#sphx-glr-auto-examples-model-selection-plot-cv-predict-py
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=100,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title("Actual vs. Predicted values")
    PredictionErrorDisplay.from_predictions(
        y_true=y_true,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=100,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title("Residuals vs. Predicted Values")
    fig.suptitle("Plotting cross-validated predictions " + label)
    plt.tight_layout()
    plt.show()

# %%
def min_shift(list1, list2):
    list1 = np.array(list1)
    list2 = np.array(list2)
    if list1.ndim == 2:
        for i in range(len(list1)):
            if np.min([list1, list2]) > 0:
                continue
            min = np.min([list1[i], list2[i]])
            list1[i] -= min
            list2[i] -= min
        return list1, list2

    min = np.min([list1, list2])
    list1 = list1 - min
    list2 = list1 - min

    return list1, list2

# %%
for label, y_pred, y_true in zip(labels_list, pred_list, true_list):
    print(f"===== {label} results =====")
    print("MAE: ", metrics.mean_absolute_error(y_true, y_pred))
    print("MSE: ", metrics.mean_squared_error(y_true, y_pred))
    print("RMSE: ", metrics.mean_squared_error(y_true, y_pred, squared=False))
    print("r2_score: ", metrics.r2_score(y_true, y_pred))
    try:
        print("MSLE: ", metrics.mean_squared_log_error(y_true, y_pred))
    except ValueError as err:
        y_true_shift, y_pred_shift = min_shift(y_true, y_pred)
        print(
            "MSLE_min_shifted: ",
            metrics.mean_squared_log_error(y_true_shift, y_pred_shift),
        )
    print("MAPE: ", metrics.mean_absolute_percentage_error(y_true, y_pred))
# Out:
# ===== gaps results =====
# MAE:  122.01841766357423
# MSE:  15450.299479602043
# RMSE:  124.29923362435524
# r2_score:  -145.43164972292612
# MSLE:  17.10640762688082
# MAPE:  4.165745817556091e+17
# ===== flank_wear results =====
# MAE:  436.2371608479818
# MSE:  198742.35624035005
# RMSE:  445.80528960561924
# r2_score:  -11.404066079932694
# MSLE_min_shifted:  0.2879464027501957
# MAPE:  4.585491003995415
# ===== overhang results =====
# MAE:  94.29299957275391
# MSE:  9107.420816209697
# RMSE:  95.43280786086981
# r2_score:  -450.4777972720091
# MSLE:  4.484315492982151
# MAPE:  8.601726013910678
# ===== multi results =====
# MAE:  217.51619269476998
# MSE:  74433.35884538727
# RMSE:  221.84577703028143
# r2_score:  -202.43783769162266
# MSLE_min_shifted:  12.320078455951972
# MAPE:  1.3885819391853637e+17
